# %% [markdown]
# ## AIGCDetectBenchmark

# %% [markdown]
# ## Install requirement

# %%
# !git clone https://github.com/chuangchuangtan/NPR-DeepfakeDetection.git

# %%
# !pip install ftfy -q
# !pip install natsort -q
# !pip install blobfile -q
#!pip install mpi4py -q
# !pip install comet_ml -q
# !pip install grad-cam -q

# %%
# !pip install tensorboardX -q
# !apt-get install -y unzip -q
# !apt-get install -y zip -q
# !pip install regex -q
# !pip install imageio -q
# !pip install opencv-python -q
# !apt-get install -y libgl1-mesa-glx -q
# !pip install scikit-learn -q
# !pip install scikit-image -q
# !pip install gdown -q
# !pip install pickleshare -q

# %%
# %cd /workspace/NPR-DeepfakeDetection
# Out:
# /workspace/NPR-DeepfakeDetection

# %% [markdown]
# ## Train

# %%
#NRP
# !python train.py \
--name NRP-4class-resnet-car-cat-chair-horse \
--dataroot /workspace/datasets/ForenSynths_train_val \
--classes car,cat,chair,horse --batch_size 32 --delr_freq 10 --lr 0.0002 --niter 50
# Out:
# ----------------- Options ---------------
#                      arch: res50
#                batch_size: 32                            	[default: 64]
#                     beta1: 0.9
#                 blur_prob: 0
#                  blur_sig: 0.5
#           checkpoints_dir: ./checkpoints
#                 class_bal: False
#                   classes: car,cat,chair,horse           	[default: ]
#            continue_train: False
#                  cropSize: 224
#                  data_aug: False
#                  dataroot: /workspace/datasets/ForenSynths_train_val	[default: ./dataset/]
#                 delr_freq: 10                            	[default: 20]
#           earlystop_epoch: 15
#                     epoch: latest
#               epoch_count: 1
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                   isTrain: True                          	[default: None]
#                jpg_method: cv2
#                  jpg_prob: 0
#                  jpg_qual: 75
#                last_epoch: -1
#                  loadSize: 256
#                 loss_freq: 400
#                        lr: 0.0002                        	[default: 0.0001]
#                      mode: binary
#                      name: NRP-4class-resnet-car-cat-chair-horse2024_06_19_10_23_11	[default: experiment_name]
#                 new_optim: False
#                     niter: 50                            	[default: 1000]
#                   no_flip: False
#               num_threads: 8
#                     optim: adam
#            resize_or_crop: scale_and_crop
#                 rz_interp: bilinear
#           save_epoch_freq: 20
#          save_latest_freq: 2000
#            serial_batches: False
#                    suffix:
#               train_split: train
#                 val_split: val
# ----------------- End -------------------
# train.py  --name  NRP-4class-resnet-car-cat-chair-horse  --dataroot  /workspace/datasets/ForenSynths_train_val  --classes  car,cat,chair,horse  --batch_size  32  --delr_freq  10  --lr  0.0002  --niter  50
# cwd: /workspace/NPR-DeepfakeDetection
# (Val @ epoch 0) acc: 0.494375; ap: 0.49289557478726964
# acc increment 0.0 --> 0.494375 - saving best model
# Saving model ./checkpoints/NRP-4class-resnet-car-cat-chair-horse2024_06_19_10_23_11/model_epoch_best.pth
# (Val @ epoch 1) acc: 0.510625; ap: 0.5422163141436337
# acc increment 0.494375 --> 0.510625 - saving best model
# Saving model ./checkpoints/NRP-4class-resnet-car-cat-chair-horse2024_06_19_10_23_11/model_epoch_best.pth
# (Val @ epoch 2) acc: 0.564375; ap: 0.5943735341549081
# acc increment 0.510625 --> 0.564375 - saving best model
# Saving model ./checkpoints/NRP-4class-resnet-car-cat-chair-horse2024_06_19_10_23_11/model_epoch_best.pth
# (Val @ epoch 3) acc: 0.675625; ap: 0.7454029299765057
# acc increment 0.564375 --> 0.675625 - saving best model
# Saving model ./checkpoints/NRP-4class-resnet-car-cat-chair-horse2024_06_19_10_23_11/model_epoch_best.pth
# (Val @ epoch 4) acc: 0.59; ap: 0.835906061403884
# (Val @ epoch 5) acc: 0.58375; ap: 0.6822510271477691
# (Val @ epoch 6) acc: 0.8475; ap: 0.9540491355427296
# acc increment 0.675625 --> 0.8475 - saving best model
# Saving model ./checkpoints/NRP-4class-resnet-car-cat-chair-horse2024_06_19_10_23_11/model_epoch_best.pth
# 2024_06_19_10_24_47 Train loss: 0.4312288463115692 at step: 400 lr 0.0002
# (Val @ epoch 7) acc: 0.790625; ap: 0.952814228531969
# (Val @ epoch 8) acc: 0.910625; ap: 0.9740572071245555
# acc increment 0.8475 --> 0.910625 - saving best model
# Saving model ./checkpoints/NRP-4class-resnet-car-cat-chair-horse2024_06_19_10_23_11/model_epoch_best.pth
# (Val @ epoch 9) acc: 0.8625; ap: 0.9496694281305568
# 2024_06_19_10_25_24 changing lr at the end of epoch 10, iters 550
# *************************
# Changing lr from 0.0002 to 0.00018
# *************************
# (Val @ epoch 10) acc: 0.84; ap: 0.957000421493304
# (Val @ epoch 11) acc: 0.9275; ap: 0.9834618252848388
# acc increment 0.910625 --> 0.9275 - saving best model
# Saving model ./checkpoints/NRP-4class-resnet-car-cat-chair-horse2024_06_19_10_23_11/model_epoch_best.pth
# (Val @ epoch 12) acc: 0.92; ap: 0.9803900419987999
# (Val @ epoch 13) acc: 0.925625; ap: 0.98256286510012
# (Val @ epoch 14) acc: 0.935; ap: 0.9858033780140617
# acc increment 0.9275 --> 0.935 - saving best model
# Saving model ./checkpoints/NRP-4class-resnet-car-cat-chair-horse2024_06_19_10_23_11/model_epoch_best.pth
# 2024_06_19_10_26_25 Train loss: 0.04726321995258331 at step: 800 lr 0.00018
# (Val @ epoch 15) acc: 0.93375; ap: 0.9864667769554382
# (Val @ epoch 16) acc: 0.9425; ap: 0.9879985800007299
# acc increment 0.935 --> 0.9425 - saving best model
# Saving model ./checkpoints/NRP-4class-resnet-car-cat-chair-horse2024_06_19_10_23_11/model_epoch_best.pth
# (Val @ epoch 17) acc: 0.940625; ap: 0.9880922113473416
# (Val @ epoch 18) acc: 0.94125; ap: 0.989360189425086
# (Val @ epoch 19) acc: 0.945; ap: 0.9879529261190724
# acc increment 0.9425 --> 0.945 - saving best model
# Saving model ./checkpoints/NRP-4class-resnet-car-cat-chair-horse2024_06_19_10_23_11/model_epoch_best.pth
# 2024_06_19_10_27_27 changing lr at the end of epoch 20, iters 1050
# *************************
# Changing lr from 0.00018 to 0.000162
# *************************
# (Val @ epoch 20) acc: 0.935; ap: 0.9859366131955818
# (Val @ epoch 21) acc: 0.955625; ap: 0.9935470524120942
# acc increment 0.945 --> 0.955625 - saving best model
# Saving model ./checkpoints/NRP-4class-resnet-car-cat-chair-horse2024_06_19_10_23_11/model_epoch_best.pth
# (Val @ epoch 22) acc: 0.951875; ap: 0.9898359221672449
# 2024_06_19_10_28_05 Train loss: 0.04045581817626953 at step: 1200 lr 0.000162
# (Val @ epoch 23) acc: 0.95625; ap: 0.9916875298338036
# acc increment 0.955625 --> 0.95625 - saving best model
# Saving model ./checkpoints/NRP-4class-resnet-car-cat-chair-horse2024_06_19_10_23_11/model_epoch_best.pth
# (Val @ epoch 24) acc: 0.9475; ap: 0.9914589551537195
# (Val @ epoch 25) acc: 0.920625; ap: 0.9820725491587848
# (Val @ epoch 26) acc: 0.965625; ap: 0.9960370435795411
# acc increment 0.95625 --> 0.965625 - saving best model
# Saving model ./checkpoints/NRP-4class-resnet-car-cat-chair-horse2024_06_19_10_23_11/model_epoch_best.pth
# (Val @ epoch 27) acc: 0.94875; ap: 0.9916759101104963
# (Val @ epoch 28) acc: 0.97; ap: 0.995890371841006
# acc increment 0.965625 --> 0.97 - saving best model
# Saving model ./checkpoints/NRP-4class-resnet-car-cat-chair-horse2024_06_19_10_23_11/model_epoch_best.pth
# (Val @ epoch 29) acc: 0.961875; ap: 0.9942805097598099
# 2024_06_19_10_29_31 changing lr at the end of epoch 30, iters 1550
# *************************
# Changing lr from 0.000162 to 0.00014580000000000002
# *************************
# (Val @ epoch 30) acc: 0.9625; ap: 0.9933768652976095
# 2024_06_19_10_29_43 Train loss: 0.004868604708462954 at step: 1600 lr 0.00014580000000000002
# (Val @ epoch 31) acc: 0.958125; ap: 0.9945424175677452
# (Val @ epoch 32) acc: 0.95; ap: 0.9961439895845396
# (Val @ epoch 33) acc: 0.9425; ap: 0.9935536577866819
# (Val @ epoch 34) acc: 0.966875; ap: 0.9970338168665064
# (Val @ epoch 35) acc: 0.953125; ap: 0.9926694856312184
# (Val @ epoch 36) acc: 0.96875; ap: 0.9966113444943575
# (Val @ epoch 37) acc: 0.936875; ap: 0.991703502461424
# (Val @ epoch 38) acc: 0.959375; ap: 0.9945252852671334
# 2024_06_19_10_31_22 Train loss: 0.011997923254966736 at step: 2000 lr 0.00014580000000000002
# (Val @ epoch 39) acc: 0.960625; ap: 0.9950282804572605
# 2024_06_19_10_31_34 changing lr at the end of epoch 40, iters 2050
# *************************
# Changing lr from 0.00014580000000000005 to 0.00013122000000000003
# *************************
# (Val @ epoch 40) acc: 0.960625; ap: 0.9950153065563738
# (Val @ epoch 41) acc: 0.975; ap: 0.997630523244826
# acc increment 0.97 --> 0.975 - saving best model
# Saving model ./checkpoints/NRP-4class-resnet-car-cat-chair-horse2024_06_19_10_23_11/model_epoch_best.pth
# (Val @ epoch 42) acc: 0.975; ap: 0.9977675359454103
# (Val @ epoch 43) acc: 0.9725; ap: 0.9970859105061356
# (Val @ epoch 44) acc: 0.973125; ap: 0.9980795141123131
# (Val @ epoch 45) acc: 0.96875; ap: 0.9957661881930396
# (Val @ epoch 46) acc: 0.96625; ap: 0.9956474872358256
# 2024_06_19_10_33_01 Train loss: 0.008120505139231682 at step: 2400 lr 0.00013122000000000003
# (Val @ epoch 47) acc: 0.975625; ap: 0.99705686492872
# acc increment 0.975 --> 0.975625 - saving best model
# Saving model ./checkpoints/NRP-4class-resnet-car-cat-chair-horse2024_06_19_10_23_11/model_epoch_best.pth
# (Val @ epoch 48) acc: 0.969375; ap: 0.9948014942408406
# (Val @ epoch 49) acc: 0.96875; ap: 0.9946671098844921
# *************************
# 2024_06_19_10_33_29
# Traceback (most recent call last):
#   File "/workspace/NPR-DeepfakeDetection/train.py", line 114, in <module>
#     model.eval();testmodel()
#   File "/workspace/NPR-DeepfakeDetection/train.py", line 67, in testmodel
#     Testopt.classes = os.listdir(Testopt.dataroot) if multiclass[v_id] else ['']
# FileNotFoundError: [Errno 2] No such file or directory: '/workspace/datasets/ForenSynths_train_val/test/progan'

# %%
#Gaussian blur
# !python train.py \
--name Gaussblur-4class-resnet-car-cat-chair-horse \
--dataroot /workspace/datasets/ForenSynths_train_val \
--classes car,cat,chair,horse --batch_size 32 --delr_freq 10 --lr 0.0002 --niter 100
# Out:
# ----------------- Options ---------------
#                      arch: res50
#                batch_size: 32                            	[default: 64]
#                     beta1: 0.9
#                 blur_prob: 0
#                  blur_sig: 0.5
#           checkpoints_dir: ./checkpoints
#                 class_bal: False
#                   classes: car,cat,chair,horse           	[default: ]
#            continue_train: False
#                  cropSize: 224
#                  data_aug: False
#                  dataroot: /workspace/datasets/ForenSynths_train_val	[default: ./dataset/]
#                 delr_freq: 10                            	[default: 20]
#           earlystop_epoch: 15
#                     epoch: latest
#               epoch_count: 1
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                   isTrain: True                          	[default: None]
#                jpg_method: cv2
#                  jpg_prob: 0
#                  jpg_qual: 75
#                last_epoch: -1
#                  loadSize: 256
#                 loss_freq: 400
#                        lr: 0.0002                        	[default: 0.0001]
#                      mode: binary
#                      name: Gaussblur-4class-resnet-car-cat-chair-horse2024_06_19_02_28_49	[default: experiment_name]
#                 new_optim: False
#                     niter: 100                           	[default: 1000]
#                   no_flip: False
#               num_threads: 8
#                     optim: adam
#            resize_or_crop: scale_and_crop
#                 rz_interp: bilinear
#           save_epoch_freq: 20
#          save_latest_freq: 2000
#            serial_batches: False
#                    suffix:
#               train_split: train
#                 val_split: val
# ----------------- End -------------------
# train.py  --name  Gaussblur-4class-resnet-car-cat-chair-horse  --dataroot  /workspace/datasets/ForenSynths_train_val  --classes  car,cat,chair,horse  --batch_size  32  --delr_freq  10  --lr  0.0002  --niter  100
# cwd: /workspace/NPR-DeepfakeDetection
# (Val @ epoch 0) acc: 0.495625; ap: 0.49368532346910127
# acc increment 0.0 --> 0.495625 - saving best model
# Saving model ./checkpoints/Gaussblur-4class-resnet-car-cat-chair-horse2024_06_19_02_28_49/model_epoch_best.pth
# (Val @ epoch 1) acc: 0.54125; ap: 0.5360800420474618
# acc increment 0.495625 --> 0.54125 - saving best model
# Saving model ./checkpoints/Gaussblur-4class-resnet-car-cat-chair-horse2024_06_19_02_28_49/model_epoch_best.pth
# (Val @ epoch 2) acc: 0.651875; ap: 0.6952261996649893
# acc increment 0.54125 --> 0.651875 - saving best model
# Saving model ./checkpoints/Gaussblur-4class-resnet-car-cat-chair-horse2024_06_19_02_28_49/model_epoch_best.pth
# (Val @ epoch 3) acc: 0.701875; ap: 0.7656236309679457
# acc increment 0.651875 --> 0.701875 - saving best model
# Saving model ./checkpoints/Gaussblur-4class-resnet-car-cat-chair-horse2024_06_19_02_28_49/model_epoch_best.pth
# (Val @ epoch 4) acc: 0.685; ap: 0.8499115052211703
# (Val @ epoch 5) acc: 0.863125; ap: 0.9329305915966661
# acc increment 0.701875 --> 0.863125 - saving best model
# Saving model ./checkpoints/Gaussblur-4class-resnet-car-cat-chair-horse2024_06_19_02_28_49/model_epoch_best.pth
# (Val @ epoch 6) acc: 0.8625; ap: 0.941882567240704
# 2024_06_19_02_30_24 Train loss: 0.23079684376716614 at step: 400 lr 0.0002
# (Val @ epoch 7) acc: 0.698125; ap: 0.7983645858579678
# (Val @ epoch 8) acc: 0.909375; ap: 0.9801435792134141
# acc increment 0.863125 --> 0.909375 - saving best model
# Saving model ./checkpoints/Gaussblur-4class-resnet-car-cat-chair-horse2024_06_19_02_28_49/model_epoch_best.pth
# (Val @ epoch 9) acc: 0.929375; ap: 0.9833464228624773
# acc increment 0.909375 --> 0.929375 - saving best model
# Saving model ./checkpoints/Gaussblur-4class-resnet-car-cat-chair-horse2024_06_19_02_28_49/model_epoch_best.pth
# 2024_06_19_02_31_01 changing lr at the end of epoch 10, iters 550
# *************************
# Changing lr from 0.0002 to 0.00018
# *************************
# (Val @ epoch 10) acc: 0.83625; ap: 0.9476836514130691
# (Val @ epoch 11) acc: 0.936875; ap: 0.9863747954118999
# acc increment 0.929375 --> 0.936875 - saving best model
# Saving model ./checkpoints/Gaussblur-4class-resnet-car-cat-chair-horse2024_06_19_02_28_49/model_epoch_best.pth
# (Val @ epoch 12) acc: 0.95625; ap: 0.9932561899855377
# acc increment 0.936875 --> 0.95625 - saving best model
# Saving model ./checkpoints/Gaussblur-4class-resnet-car-cat-chair-horse2024_06_19_02_28_49/model_epoch_best.pth
# (Val @ epoch 13) acc: 0.95375; ap: 0.9915695983518694
# (Val @ epoch 14) acc: 0.940625; ap: 0.9916264292641376
# 2024_06_19_02_32_03 Train loss: 0.15977677702903748 at step: 800 lr 0.00018
# (Val @ epoch 15) acc: 0.934375; ap: 0.9922211767853631
# (Val @ epoch 16) acc: 0.96875; ap: 0.9947892782764314
# acc increment 0.95625 --> 0.96875 - saving best model
# Saving model ./checkpoints/Gaussblur-4class-resnet-car-cat-chair-horse2024_06_19_02_28_49/model_epoch_best.pth
# (Val @ epoch 17) acc: 0.96125; ap: 0.9955278007416083
# (Val @ epoch 18) acc: 0.92; ap: 0.9899009985729051
# (Val @ epoch 19) acc: 0.96; ap: 0.9932286399092861
# 2024_06_19_02_33_05 changing lr at the end of epoch 20, iters 1050
# *************************
# Changing lr from 0.00018 to 0.000162
# *************************
# (Val @ epoch 20) acc: 0.945625; ap: 0.9923119283445252
# (Val @ epoch 21) acc: 0.954375; ap: 0.9916319517132854
# (Val @ epoch 22) acc: 0.964375; ap: 0.9949910757360713
# 2024_06_19_02_33_42 Train loss: 0.02685895934700966 at step: 1200 lr 0.000162
# (Val @ epoch 23) acc: 0.951875; ap: 0.9944891424623737
# (Val @ epoch 24) acc: 0.954375; ap: 0.9954352324767197
# (Val @ epoch 25) acc: 0.94125; ap: 0.9950102393324035
# (Val @ epoch 26) acc: 0.959375; ap: 0.9889151729590613
# (Val @ epoch 27) acc: 0.966875; ap: 0.995852330110403
# (Val @ epoch 28) acc: 0.929375; ap: 0.9965567916713085
# (Val @ epoch 29) acc: 0.965625; ap: 0.9946904142242462
# 2024_06_19_02_35_08 changing lr at the end of epoch 30, iters 1550
# *************************
# Changing lr from 0.000162 to 0.00014580000000000002
# *************************
# (Val @ epoch 30) acc: 0.976875; ap: 0.9981236797581192
# acc increment 0.96875 --> 0.976875 - saving best model
# Saving model ./checkpoints/Gaussblur-4class-resnet-car-cat-chair-horse2024_06_19_02_28_49/model_epoch_best.pth
# 2024_06_19_02_35_20 Train loss: 0.015131200663745403 at step: 1600 lr 0.00014580000000000002
# (Val @ epoch 31) acc: 0.968125; ap: 0.9984243670325351
# (Val @ epoch 32) acc: 0.97625; ap: 0.9984880687482748
# (Val @ epoch 33) acc: 0.97375; ap: 0.9970648525452898
# (Val @ epoch 34) acc: 0.95; ap: 0.9956879055241821
# (Val @ epoch 35) acc: 0.973125; ap: 0.9972770261178556
# (Val @ epoch 36) acc: 0.9825; ap: 0.9982620155240315
# acc increment 0.976875 --> 0.9825 - saving best model
# Saving model ./checkpoints/Gaussblur-4class-resnet-car-cat-chair-horse2024_06_19_02_28_49/model_epoch_best.pth
# (Val @ epoch 37) acc: 0.983125; ap: 0.9982138978168146
# acc increment 0.9825 --> 0.983125 - saving best model
# Saving model ./checkpoints/Gaussblur-4class-resnet-car-cat-chair-horse2024_06_19_02_28_49/model_epoch_best.pth
# (Val @ epoch 38) acc: 0.980625; ap: 0.9984313466959838
# ^C
# Traceback (most recent call last):
#   File "/workspace/NPR-DeepfakeDetection/train.py", line 88, in <module>
#     model.optimize_parameters()
#   File "/workspace/NPR-DeepfakeDetection/networks/trainer.py", line 64, in optimize_parameters
#     self.loss.backward()
#   File "/opt/conda/lib/python3.10/site-packages/torch/_tensor.py", line 522, in backward
#     torch.autograd.backward(
#   File "/opt/conda/lib/python3.10/site-packages/torch/autograd/__init__.py", line 266, in backward
#     Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# KeyboardInterrupt

# %%
#Highpass blur
# !python train.py \
--name NPR-highpass-4class-resnet-car-cat-chair-horse \
--dataroot /workspace/datasets/ForenSynths_train_val \
--classes car,cat,chair,horse --batch_size 32 --delr_freq 10 --lr 0.0002 --niter 50
# Out:
# ----------------- Options ---------------
#                      arch: res50
#                batch_size: 32                            	[default: 64]
#                     beta1: 0.9
#                 blur_prob: 0
#                  blur_sig: 0.5
#           checkpoints_dir: ./checkpoints
#                 class_bal: False
#                   classes: car,cat,chair,horse           	[default: ]
#            continue_train: False
#                  cropSize: 224
#                  data_aug: False
#                  dataroot: /workspace/datasets/ForenSynths_train_val	[default: ./dataset/]
#                 delr_freq: 10                            	[default: 20]
#           earlystop_epoch: 15
#                     epoch: latest
#               epoch_count: 1
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                   isTrain: True                          	[default: None]
#                jpg_method: cv2
#                  jpg_prob: 0
#                  jpg_qual: 75
#                last_epoch: -1
#                  loadSize: 256
#                 loss_freq: 400
#                        lr: 0.0002                        	[default: 0.0001]
#                      mode: binary
#                      name: NPR-highpass-4class-resnet-car-cat-chair-horse2024_06_19_03_02_23	[default: experiment_name]
#                 new_optim: False
#                     niter: 50                            	[default: 1000]
#                   no_flip: False
#               num_threads: 8
#                     optim: adam
#            resize_or_crop: scale_and_crop
#                 rz_interp: bilinear
#           save_epoch_freq: 20
#          save_latest_freq: 2000
#            serial_batches: False
#                    suffix:
#               train_split: train
#                 val_split: val
# ----------------- End -------------------
# train.py  --name  NPR-highpass-4class-resnet-car-cat-chair-horse  --dataroot  /workspace/datasets/ForenSynths_train_val  --classes  car,cat,chair,horse  --batch_size  32  --delr_freq  10  --lr  0.0002  --niter  50
# cwd: /workspace/NPR-DeepfakeDetection
# (Val @ epoch 0) acc: 0.495; ap: 0.4888359050234892
# acc increment 0.0 --> 0.495 - saving best model
# Saving model ./checkpoints/NPR-highpass-4class-resnet-car-cat-chair-horse2024_06_19_03_02_23/model_epoch_best.pth
# (Val @ epoch 1) acc: 0.510625; ap: 0.5150200096192246
# acc increment 0.495 --> 0.510625 - saving best model
# Saving model ./checkpoints/NPR-highpass-4class-resnet-car-cat-chair-horse2024_06_19_03_02_23/model_epoch_best.pth
# (Val @ epoch 2) acc: 0.5025; ap: 0.5182460969554439
# (Val @ epoch 3) acc: 0.511875; ap: 0.5238646861555315
# acc increment 0.510625 --> 0.511875 - saving best model
# Saving model ./checkpoints/NPR-highpass-4class-resnet-car-cat-chair-horse2024_06_19_03_02_23/model_epoch_best.pth
# (Val @ epoch 4) acc: 0.52125; ap: 0.5266026486493516
# acc increment 0.511875 --> 0.52125 - saving best model
# Saving model ./checkpoints/NPR-highpass-4class-resnet-car-cat-chair-horse2024_06_19_03_02_23/model_epoch_best.pth
# (Val @ epoch 5) acc: 0.51125; ap: 0.512404671848645
# (Val @ epoch 6) acc: 0.53375; ap: 0.5381729611456649
# acc increment 0.52125 --> 0.53375 - saving best model
# Saving model ./checkpoints/NPR-highpass-4class-resnet-car-cat-chair-horse2024_06_19_03_02_23/model_epoch_best.pth
# 2024_06_19_03_04_01 Train loss: 0.6703981161117554 at step: 400 lr 0.0002
# (Val @ epoch 7) acc: 0.5; ap: 0.5127213400629995
# (Val @ epoch 8) acc: 0.5175; ap: 0.5378823841730225
# (Val @ epoch 9) acc: 0.52; ap: 0.5337192395131556
# 2024_06_19_03_04_40 changing lr at the end of epoch 10, iters 550
# *************************
# Changing lr from 0.0002 to 0.00018
# *************************
# (Val @ epoch 10) acc: 0.566875; ap: 0.5649852768264666
# acc increment 0.53375 --> 0.566875 - saving best model
# Saving model ./checkpoints/NPR-highpass-4class-resnet-car-cat-chair-horse2024_06_19_03_02_23/model_epoch_best.pth
# (Val @ epoch 11) acc: 0.524375; ap: 0.577914512212411
# (Val @ epoch 12) acc: 0.56375; ap: 0.602681779049178
# (Val @ epoch 13) acc: 0.566875; ap: 0.6073863926488821
# (Val @ epoch 14) acc: 0.571875; ap: 0.6681596025988652
# acc increment 0.566875 --> 0.571875 - saving best model
# Saving model ./checkpoints/NPR-highpass-4class-resnet-car-cat-chair-horse2024_06_19_03_02_23/model_epoch_best.pth
# 2024_06_19_03_05_43 Train loss: 0.6543283462524414 at step: 800 lr 0.00018
# (Val @ epoch 15) acc: 0.526875; ap: 0.5718351258118124
# (Val @ epoch 16) acc: 0.65375; ap: 0.6585055523864982
# acc increment 0.571875 --> 0.65375 - saving best model
# Saving model ./checkpoints/NPR-highpass-4class-resnet-car-cat-chair-horse2024_06_19_03_02_23/model_epoch_best.pth
# (Val @ epoch 17) acc: 0.666875; ap: 0.7354708158899548
# acc increment 0.65375 --> 0.666875 - saving best model
# Saving model ./checkpoints/NPR-highpass-4class-resnet-car-cat-chair-horse2024_06_19_03_02_23/model_epoch_best.pth
# (Val @ epoch 18) acc: 0.6725; ap: 0.7318912258487623
# acc increment 0.666875 --> 0.6725 - saving best model
# Saving model ./checkpoints/NPR-highpass-4class-resnet-car-cat-chair-horse2024_06_19_03_02_23/model_epoch_best.pth
# (Val @ epoch 19) acc: 0.5975; ap: 0.7441484148203057
# 2024_06_19_03_06_47 changing lr at the end of epoch 20, iters 1050
# *************************
# Changing lr from 0.00018 to 0.000162
# *************************
# (Val @ epoch 20) acc: 0.633125; ap: 0.7305852703535562
# (Val @ epoch 21) acc: 0.74125; ap: 0.8308680239418713
# acc increment 0.6725 --> 0.74125 - saving best model
# Saving model ./checkpoints/NPR-highpass-4class-resnet-car-cat-chair-horse2024_06_19_03_02_23/model_epoch_best.pth
# (Val @ epoch 22) acc: 0.68375; ap: 0.816050131877544
# 2024_06_19_03_07_25 Train loss: 0.28629225492477417 at step: 1200 lr 0.000162
# (Val @ epoch 23) acc: 0.7475; ap: 0.8439521568019043
# acc increment 0.74125 --> 0.7475 - saving best model
# Saving model ./checkpoints/NPR-highpass-4class-resnet-car-cat-chair-horse2024_06_19_03_02_23/model_epoch_best.pth
# (Val @ epoch 24) acc: 0.76125; ap: 0.8590660612290711
# acc increment 0.7475 --> 0.76125 - saving best model
# Saving model ./checkpoints/NPR-highpass-4class-resnet-car-cat-chair-horse2024_06_19_03_02_23/model_epoch_best.pth
# (Val @ epoch 25) acc: 0.59375; ap: 0.7677283134304078
# (Val @ epoch 26) acc: 0.74375; ap: 0.8502414872777493
# (Val @ epoch 27) acc: 0.78375; ap: 0.8801349756068758
# acc increment 0.76125 --> 0.78375 - saving best model
# Saving model ./checkpoints/NPR-highpass-4class-resnet-car-cat-chair-horse2024_06_19_03_02_23/model_epoch_best.pth
# (Val @ epoch 28) acc: 0.699375; ap: 0.8636473546688361
# (Val @ epoch 29) acc: 0.72625; ap: 0.9000801975979871
# 2024_06_19_03_08_55 changing lr at the end of epoch 30, iters 1550
# *************************
# Changing lr from 0.000162 to 0.00014580000000000002
# *************************
# (Val @ epoch 30) acc: 0.75875; ap: 0.8562968700077223
# 2024_06_19_03_09_07 Train loss: 0.1956675946712494 at step: 1600 lr 0.00014580000000000002
# (Val @ epoch 31) acc: 0.774375; ap: 0.8722625092549061
# (Val @ epoch 32) acc: 0.635625; ap: 0.8541325357355745
# (Val @ epoch 33) acc: 0.68125; ap: 0.8485555690765739
# (Val @ epoch 34) acc: 0.81875; ap: 0.9122634865720669
# acc increment 0.78375 --> 0.81875 - saving best model
# Saving model ./checkpoints/NPR-highpass-4class-resnet-car-cat-chair-horse2024_06_19_03_02_23/model_epoch_best.pth
# (Val @ epoch 35) acc: 0.795625; ap: 0.8875047127919514
# (Val @ epoch 36) acc: 0.795625; ap: 0.8981123576827008
# (Val @ epoch 37) acc: 0.84; ap: 0.9225091155091381
# acc increment 0.81875 --> 0.84 - saving best model
# Saving model ./checkpoints/NPR-highpass-4class-resnet-car-cat-chair-horse2024_06_19_03_02_23/model_epoch_best.pth
# (Val @ epoch 38) acc: 0.748125; ap: 0.896857673008437
# 2024_06_19_03_10_50 Train loss: 0.09482744336128235 at step: 2000 lr 0.00014580000000000002
# (Val @ epoch 39) acc: 0.783125; ap: 0.9136656535738659
# 2024_06_19_03_11_02 changing lr at the end of epoch 40, iters 2050
# *************************
# Changing lr from 0.00014580000000000005 to 0.00013122000000000003
# *************************
# (Val @ epoch 40) acc: 0.8225; ap: 0.9301212006851347
# (Val @ epoch 41) acc: 0.71875; ap: 0.9002298062528149
# (Val @ epoch 42) acc: 0.83375; ap: 0.9250832415480889
# (Val @ epoch 43) acc: 0.71; ap: 0.8854322569215767
# (Val @ epoch 44) acc: 0.75; ap: 0.9093783727928745
# (Val @ epoch 45) acc: 0.70875; ap: 0.9053907780399462
# (Val @ epoch 46) acc: 0.7775; ap: 0.9222728457736098
# 2024_06_19_03_12_32 Train loss: 0.14480625092983246 at step: 2400 lr 0.00013122000000000003
# (Val @ epoch 47) acc: 0.83625; ap: 0.9270991960938851
# (Val @ epoch 48) acc: 0.785; ap: 0.9318144086254235
# (Val @ epoch 49) acc: 0.8275; ap: 0.9131802596221527
# *************************
# 2024_06_19_03_13_02
# Traceback (most recent call last):
#   File "/workspace/NPR-DeepfakeDetection/train.py", line 114, in <module>
#     model.eval();testmodel()
#   File "/workspace/NPR-DeepfakeDetection/train.py", line 67, in testmodel
#     Testopt.classes = os.listdir(Testopt.dataroot) if multiclass[v_id] else ['']
# FileNotFoundError: [Errno 2] No such file or directory: '/workspace/datasets/ForenSynths_train_val/test/progan'

# %%
#Lowpass blur
# !python train.py \
--name NPR-lowpass-4class-resnet-car-cat-chair-horse \
--dataroot /workspace/datasets/ForenSynths_train_val \
--classes car,cat,chair,horse --batch_size 32 --delr_freq 10 --lr 0.0002 --niter 50
# Out:
# ----------------- Options ---------------
#                      arch: res50
#                batch_size: 32                            	[default: 64]
#                     beta1: 0.9
#                 blur_prob: 0
#                  blur_sig: 0.5
#           checkpoints_dir: ./checkpoints
#                 class_bal: False
#                   classes: car,cat,chair,horse           	[default: ]
#            continue_train: False
#                  cropSize: 224
#                  data_aug: False
#                  dataroot: /workspace/datasets/ForenSynths_train_val	[default: ./dataset/]
#                 delr_freq: 10                            	[default: 20]
#           earlystop_epoch: 15
#                     epoch: latest
#               epoch_count: 1
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                   isTrain: True                          	[default: None]
#                jpg_method: cv2
#                  jpg_prob: 0
#                  jpg_qual: 75
#                last_epoch: -1
#                  loadSize: 256
#                 loss_freq: 400
#                        lr: 0.0002                        	[default: 0.0001]
#                      mode: binary
#                      name: NPR-lowpass-4class-resnet-car-cat-chair-horse2024_06_19_03_28_12	[default: experiment_name]
#                 new_optim: False
#                     niter: 50                            	[default: 1000]
#                   no_flip: False
#               num_threads: 8
#                     optim: adam
#            resize_or_crop: scale_and_crop
#                 rz_interp: bilinear
#           save_epoch_freq: 20
#          save_latest_freq: 2000
#            serial_batches: False
#                    suffix:
#               train_split: train
#                 val_split: val
# ----------------- End -------------------
# train.py  --name  NPR-lowpass-4class-resnet-car-cat-chair-horse  --dataroot  /workspace/datasets/ForenSynths_train_val  --classes  car,cat,chair,horse  --batch_size  32  --delr_freq  10  --lr  0.0002  --niter  50
# cwd: /workspace/NPR-DeepfakeDetection
# (Val @ epoch 0) acc: 0.498125; ap: 0.4923104749827393
# acc increment 0.0 --> 0.498125 - saving best model
# Saving model ./checkpoints/NPR-lowpass-4class-resnet-car-cat-chair-horse2024_06_19_03_28_12/model_epoch_best.pth
# (Val @ epoch 1) acc: 0.619375; ap: 0.6916645470432583
# acc increment 0.498125 --> 0.619375 - saving best model
# Saving model ./checkpoints/NPR-lowpass-4class-resnet-car-cat-chair-horse2024_06_19_03_28_12/model_epoch_best.pth
# (Val @ epoch 2) acc: 0.6975; ap: 0.7963584568245985
# acc increment 0.619375 --> 0.6975 - saving best model
# Saving model ./checkpoints/NPR-lowpass-4class-resnet-car-cat-chair-horse2024_06_19_03_28_12/model_epoch_best.pth
# (Val @ epoch 3) acc: 0.80875; ap: 0.916057894652035
# acc increment 0.6975 --> 0.80875 - saving best model
# Saving model ./checkpoints/NPR-lowpass-4class-resnet-car-cat-chair-horse2024_06_19_03_28_12/model_epoch_best.pth
# (Val @ epoch 4) acc: 0.8; ap: 0.9414906028628147
# (Val @ epoch 5) acc: 0.79625; ap: 0.936775895773388
# (Val @ epoch 6) acc: 0.886875; ap: 0.9693662942360741
# acc increment 0.80875 --> 0.886875 - saving best model
# Saving model ./checkpoints/NPR-lowpass-4class-resnet-car-cat-chair-horse2024_06_19_03_28_12/model_epoch_best.pth
# 2024_06_19_03_29_50 Train loss: 0.21990740299224854 at step: 400 lr 0.0002
# (Val @ epoch 7) acc: 0.908125; ap: 0.9707278961893289
# acc increment 0.886875 --> 0.908125 - saving best model
# Saving model ./checkpoints/NPR-lowpass-4class-resnet-car-cat-chair-horse2024_06_19_03_28_12/model_epoch_best.pth
# (Val @ epoch 8) acc: 0.903125; ap: 0.973091773795417
# (Val @ epoch 9) acc: 0.865; ap: 0.9824728313139777
# 2024_06_19_03_30_28 changing lr at the end of epoch 10, iters 550
# *************************
# Changing lr from 0.0002 to 0.00018
# *************************
# (Val @ epoch 10) acc: 0.913125; ap: 0.9787111595032545
# acc increment 0.908125 --> 0.913125 - saving best model
# Saving model ./checkpoints/NPR-lowpass-4class-resnet-car-cat-chair-horse2024_06_19_03_28_12/model_epoch_best.pth
# (Val @ epoch 11) acc: 0.914375; ap: 0.9730011187131494
# acc increment 0.913125 --> 0.914375 - saving best model
# Saving model ./checkpoints/NPR-lowpass-4class-resnet-car-cat-chair-horse2024_06_19_03_28_12/model_epoch_best.pth
# (Val @ epoch 12) acc: 0.903125; ap: 0.9779529898957856
# (Val @ epoch 13) acc: 0.935; ap: 0.9855961409166286
# acc increment 0.914375 --> 0.935 - saving best model
# Saving model ./checkpoints/NPR-lowpass-4class-resnet-car-cat-chair-horse2024_06_19_03_28_12/model_epoch_best.pth
# (Val @ epoch 14) acc: 0.923125; ap: 0.9831165624946996
# 2024_06_19_03_31_31 Train loss: 0.12025018036365509 at step: 800 lr 0.00018
# (Val @ epoch 15) acc: 0.944375; ap: 0.9875870792046892
# acc increment 0.935 --> 0.944375 - saving best model
# Saving model ./checkpoints/NPR-lowpass-4class-resnet-car-cat-chair-horse2024_06_19_03_28_12/model_epoch_best.pth
# (Val @ epoch 16) acc: 0.944375; ap: 0.9881986509040315
# (Val @ epoch 17) acc: 0.793125; ap: 0.9739913419163482
# (Val @ epoch 18) acc: 0.915; ap: 0.9847619366970897
# (Val @ epoch 19) acc: 0.929375; ap: 0.9852224446991146
# 2024_06_19_03_32_35 changing lr at the end of epoch 20, iters 1050
# *************************
# Changing lr from 0.00018 to 0.000162
# *************************
# (Val @ epoch 20) acc: 0.843125; ap: 0.9687263097787103
# (Val @ epoch 21) acc: 0.934375; ap: 0.9923259293120781
# (Val @ epoch 22) acc: 0.9275; ap: 0.9862023273937107
# 2024_06_19_03_33_12 Train loss: 0.22596842050552368 at step: 1200 lr 0.000162
# (Val @ epoch 23) acc: 0.93625; ap: 0.994054724313052
# (Val @ epoch 24) acc: 0.943125; ap: 0.9918803540140395
# (Val @ epoch 25) acc: 0.960625; ap: 0.9929100573017386
# acc increment 0.944375 --> 0.960625 - saving best model
# Saving model ./checkpoints/NPR-lowpass-4class-resnet-car-cat-chair-horse2024_06_19_03_28_12/model_epoch_best.pth
# (Val @ epoch 26) acc: 0.961875; ap: 0.994118497236192
# acc increment 0.960625 --> 0.961875 - saving best model
# Saving model ./checkpoints/NPR-lowpass-4class-resnet-car-cat-chair-horse2024_06_19_03_28_12/model_epoch_best.pth
# (Val @ epoch 27) acc: 0.950625; ap: 0.9921405655203916
# (Val @ epoch 28) acc: 0.934375; ap: 0.9910445357792913
# (Val @ epoch 29) acc: 0.9375; ap: 0.9928657439193495
# 2024_06_19_03_34_42 changing lr at the end of epoch 30, iters 1550
# *************************
# Changing lr from 0.000162 to 0.00014580000000000002
# *************************
# (Val @ epoch 30) acc: 0.964375; ap: 0.9945931941702724
# acc increment 0.961875 --> 0.964375 - saving best model
# Saving model ./checkpoints/NPR-lowpass-4class-resnet-car-cat-chair-horse2024_06_19_03_28_12/model_epoch_best.pth
# 2024_06_19_03_34_54 Train loss: 0.037176720798015594 at step: 1600 lr 0.00014580000000000002
# (Val @ epoch 31) acc: 0.920625; ap: 0.9900831397211952
# (Val @ epoch 32) acc: 0.95375; ap: 0.9930181179879533
# (Val @ epoch 33) acc: 0.96125; ap: 0.9926426803614594
# (Val @ epoch 34) acc: 0.953125; ap: 0.9931814802563701
# (Val @ epoch 35) acc: 0.959375; ap: 0.9940497679497601
# (Val @ epoch 36) acc: 0.96; ap: 0.9942822764965897
# (Val @ epoch 37) acc: 0.946875; ap: 0.9945293868980696
# (Val @ epoch 38) acc: 0.950625; ap: 0.9919790915736453
# 2024_06_19_03_36_37 Train loss: 0.012948505580425262 at step: 2000 lr 0.00014580000000000002
# (Val @ epoch 39) acc: 0.945625; ap: 0.9946345207136689
# 2024_06_19_03_36_50 changing lr at the end of epoch 40, iters 2050
# *************************
# Changing lr from 0.00014580000000000005 to 0.00013122000000000003
# *************************
# (Val @ epoch 40) acc: 0.939375; ap: 0.9932967213854201
# (Val @ epoch 41) acc: 0.9275; ap: 0.9870293876846884
# (Val @ epoch 42) acc: 0.959375; ap: 0.9938957025863754
# (Val @ epoch 43) acc: 0.966875; ap: 0.9955208650997308
# acc increment 0.964375 --> 0.966875 - saving best model
# Saving model ./checkpoints/NPR-lowpass-4class-resnet-car-cat-chair-horse2024_06_19_03_28_12/model_epoch_best.pth
# (Val @ epoch 44) acc: 0.968125; ap: 0.9957182364231107
# acc increment 0.966875 --> 0.968125 - saving best model
# Saving model ./checkpoints/NPR-lowpass-4class-resnet-car-cat-chair-horse2024_06_19_03_28_12/model_epoch_best.pth
# (Val @ epoch 45) acc: 0.958125; ap: 0.9947393084999716
# (Val @ epoch 46) acc: 0.960625; ap: 0.9941898190360208
# 2024_06_19_03_38_19 Train loss: 0.019780311733484268 at step: 2400 lr 0.00013122000000000003
# (Val @ epoch 47) acc: 0.969375; ap: 0.9948288695921285
# acc increment 0.968125 --> 0.969375 - saving best model
# Saving model ./checkpoints/NPR-lowpass-4class-resnet-car-cat-chair-horse2024_06_19_03_28_12/model_epoch_best.pth
# (Val @ epoch 48) acc: 0.968125; ap: 0.9956143615419297
# (Val @ epoch 49) acc: 0.941875; ap: 0.9951329284610688
# *************************
# 2024_06_19_03_38_49
# Traceback (most recent call last):
#   File "/workspace/NPR-DeepfakeDetection/train.py", line 114, in <module>
#     model.eval();testmodel()
#   File "/workspace/NPR-DeepfakeDetection/train.py", line 67, in testmodel
#     Testopt.classes = os.listdir(Testopt.dataroot) if multiclass[v_id] else ['']
# FileNotFoundError: [Errno 2] No such file or directory: '/workspace/datasets/ForenSynths_train_val/test/progan'

# %%
#2Branch blur
# !python train.py \
--name NPR-2branch-4class-resnet-car-cat-chair-horse \
--dataroot /workspace/datasets/ForenSynths_train_val \
--classes car,cat,chair,horse --batch_size 32 --delr_freq 10 --lr 0.0002 --niter 50
# Out:
# ----------------- Options ---------------
#                      arch: res50
#                batch_size: 32                            	[default: 64]
#                     beta1: 0.9
#                 blur_prob: 0
#                  blur_sig: 0.5
#           checkpoints_dir: ./checkpoints
#                 class_bal: False
#                   classes: car,cat,chair,horse           	[default: ]
#            continue_train: False
#                  cropSize: 224
#                  data_aug: False
#                  dataroot: /workspace/datasets/ForenSynths_train_val	[default: ./dataset/]
#                 delr_freq: 10                            	[default: 20]
#           earlystop_epoch: 15
#                     epoch: latest
#               epoch_count: 1
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                   isTrain: True                          	[default: None]
#                jpg_method: cv2
#                  jpg_prob: 0
#                  jpg_qual: 75
#                last_epoch: -1
#                  loadSize: 256
#                 loss_freq: 400
#                        lr: 0.0002                        	[default: 0.0001]
#                      mode: binary
#                      name: NPR-2branch-4class-resnet-car-cat-chair-horse2024_06_19_04_32_24	[default: experiment_name]
#                 new_optim: False
#                     niter: 50                            	[default: 1000]
#                   no_flip: False
#               num_threads: 8
#                     optim: adam
#            resize_or_crop: scale_and_crop
#                 rz_interp: bilinear
#           save_epoch_freq: 20
#          save_latest_freq: 2000
#            serial_batches: False
#                    suffix:
#               train_split: train
#                 val_split: val
# ----------------- End -------------------
# train.py  --name  NPR-2branch-4class-resnet-car-cat-chair-horse  --dataroot  /workspace/datasets/ForenSynths_train_val  --classes  car,cat,chair,horse  --batch_size  32  --delr_freq  10  --lr  0.0002  --niter  50
# cwd: /workspace/NPR-DeepfakeDetection
# (Val @ epoch 0) acc: 0.504375; ap: 0.5225914185036042
# acc increment 0.0 --> 0.504375 - saving best model
# Saving model ./checkpoints/NPR-2branch-4class-resnet-car-cat-chair-horse2024_06_19_04_32_24/model_epoch_best.pth
# (Val @ epoch 1) acc: 0.5125; ap: 0.5921567434820434
# acc increment 0.504375 --> 0.5125 - saving best model
# Saving model ./checkpoints/NPR-2branch-4class-resnet-car-cat-chair-horse2024_06_19_04_32_24/model_epoch_best.pth
# (Val @ epoch 2) acc: 0.583125; ap: 0.6234794801227825
# acc increment 0.5125 --> 0.583125 - saving best model
# Saving model ./checkpoints/NPR-2branch-4class-resnet-car-cat-chair-horse2024_06_19_04_32_24/model_epoch_best.pth
# (Val @ epoch 3) acc: 0.574375; ap: 0.6485299314832251
# (Val @ epoch 4) acc: 0.545625; ap: 0.6578299495335405
# (Val @ epoch 5) acc: 0.535625; ap: 0.7055504020101658
# (Val @ epoch 6) acc: 0.6425; ap: 0.7428667713906554
# acc increment 0.583125 --> 0.6425 - saving best model
# Saving model ./checkpoints/NPR-2branch-4class-resnet-car-cat-chair-horse2024_06_19_04_32_24/model_epoch_best.pth
# 2024_06_19_04_35_23 Train loss: 0.14640258252620697 at step: 400 lr 0.0002
# (Val @ epoch 7) acc: 0.55125; ap: 0.6441288281744555
# (Val @ epoch 8) acc: 0.709375; ap: 0.8202456064600053
# acc increment 0.6425 --> 0.709375 - saving best model
# Saving model ./checkpoints/NPR-2branch-4class-resnet-car-cat-chair-horse2024_06_19_04_32_24/model_epoch_best.pth
# (Val @ epoch 9) acc: 0.669375; ap: 0.7805778962817345
# 2024_06_19_04_36_33 changing lr at the end of epoch 10, iters 550
# *************************
# Changing lr from 0.0002 to 0.00018
# *************************
# (Val @ epoch 10) acc: 0.681875; ap: 0.737512323800916
# (Val @ epoch 11) acc: 0.691875; ap: 0.7850280057359268
# (Val @ epoch 12) acc: 0.61875; ap: 0.8401792054051496
# (Val @ epoch 13) acc: 0.658125; ap: 0.9323982553588966
# (Val @ epoch 14) acc: 0.744375; ap: 0.9086988184008948
# acc increment 0.709375 --> 0.744375 - saving best model
# Saving model ./checkpoints/NPR-2branch-4class-resnet-car-cat-chair-horse2024_06_19_04_32_24/model_epoch_best.pth
# 2024_06_19_04_38_30 Train loss: 0.04897479712963104 at step: 800 lr 0.00018
# (Val @ epoch 15) acc: 0.69875; ap: 0.8764170100372879
# (Val @ epoch 16) acc: 0.721875; ap: 0.846086545204795
# (Val @ epoch 17) acc: 0.705625; ap: 0.8177842769181072
# (Val @ epoch 18) acc: 0.746875; ap: 0.9149018509467147
# acc increment 0.744375 --> 0.746875 - saving best model
# Saving model ./checkpoints/NPR-2branch-4class-resnet-car-cat-chair-horse2024_06_19_04_32_24/model_epoch_best.pth
# (Val @ epoch 19) acc: 0.765; ap: 0.8834658459237763
# acc increment 0.746875 --> 0.765 - saving best model
# Saving model ./checkpoints/NPR-2branch-4class-resnet-car-cat-chair-horse2024_06_19_04_32_24/model_epoch_best.pth
# 2024_06_19_04_40_27 changing lr at the end of epoch 20, iters 1050
# *************************
# Changing lr from 0.00018 to 0.000162
# *************************
# (Val @ epoch 20) acc: 0.756875; ap: 0.8788783006646956
# (Val @ epoch 21) acc: 0.705; ap: 0.8131617716500291
# (Val @ epoch 22) acc: 0.6975; ap: 0.8054456560621129
# 2024_06_19_04_41_37 Train loss: 0.09378662705421448 at step: 1200 lr 0.000162
# (Val @ epoch 23) acc: 0.755625; ap: 0.8954142336466213
# (Val @ epoch 24) acc: 0.763125; ap: 0.9387234850975599
# (Val @ epoch 25) acc: 0.81375; ap: 0.9290542267595033
# acc increment 0.765 --> 0.81375 - saving best model
# Saving model ./checkpoints/NPR-2branch-4class-resnet-car-cat-chair-horse2024_06_19_04_32_24/model_epoch_best.pth
# (Val @ epoch 26) acc: 0.861875; ap: 0.951339848610984
# acc increment 0.81375 --> 0.861875 - saving best model
# Saving model ./checkpoints/NPR-2branch-4class-resnet-car-cat-chair-horse2024_06_19_04_32_24/model_epoch_best.pth
# (Val @ epoch 27) acc: 0.7875; ap: 0.9054358244460391
# (Val @ epoch 28) acc: 0.695625; ap: 0.8846411279632789
# (Val @ epoch 29) acc: 0.73125; ap: 0.8363824713503754
# 2024_06_19_04_44_20 changing lr at the end of epoch 30, iters 1550
# *************************
# Changing lr from 0.000162 to 0.00014580000000000002
# *************************
# (Val @ epoch 30) acc: 0.786875; ap: 0.9367327315000953
# 2024_06_19_04_44_43 Train loss: 0.1562291383743286 at step: 1600 lr 0.00014580000000000002
# (Val @ epoch 31) acc: 0.70625; ap: 0.8802150931783119
# (Val @ epoch 32) acc: 0.77125; ap: 0.9230150146712675
# (Val @ epoch 33) acc: 0.703125; ap: 0.7847480384351441
# (Val @ epoch 34) acc: 0.66375; ap: 0.8336720077522337
# (Val @ epoch 35) acc: 0.668125; ap: 0.9023265822437027
# (Val @ epoch 36) acc: 0.62375; ap: 0.8801862679270577
# (Val @ epoch 37) acc: 0.714375; ap: 0.933385252437765
# (Val @ epoch 38) acc: 0.721875; ap: 0.9565977074294796
# 2024_06_19_04_47_50 Train loss: 0.17769476771354675 at step: 2000 lr 0.00014580000000000002
# (Val @ epoch 39) acc: 0.6125; ap: 0.8145282420525607
# 2024_06_19_04_48_13 changing lr at the end of epoch 40, iters 2050
# *************************
# Changing lr from 0.00014580000000000005 to 0.00013122000000000003
# *************************
# (Val @ epoch 40) acc: 0.745; ap: 0.9204257424258344
# (Val @ epoch 41) acc: 0.754375; ap: 0.9029244836255156
# (Val @ epoch 42) acc: 0.764375; ap: 0.9259506455681764
# (Val @ epoch 43) acc: 0.733125; ap: 0.9750087462286048
# (Val @ epoch 44) acc: 0.75125; ap: 0.8916097807453338
# (Val @ epoch 45) acc: 0.80625; ap: 0.9387456364731448
# (Val @ epoch 46) acc: 0.71125; ap: 0.8468361211217131
# 2024_06_19_04_50_56 Train loss: 0.001953735016286373 at step: 2400 lr 0.00013122000000000003
# (Val @ epoch 47) acc: 0.745625; ap: 0.9512167502571273
# (Val @ epoch 48) acc: 0.684375; ap: 0.9393744627981255
# (Val @ epoch 49) acc: 0.65625; ap: 0.8225459991032443
# *************************
# 2024_06_19_04_51_49
# Traceback (most recent call last):
#   File "/workspace/NPR-DeepfakeDetection/train.py", line 114, in <module>
#     model.eval();testmodel()
#   File "/workspace/NPR-DeepfakeDetection/train.py", line 67, in testmodel
#     Testopt.classes = os.listdir(Testopt.dataroot) if multiclass[v_id] else ['']
# FileNotFoundError: [Errno 2] No such file or directory: '/workspace/datasets/ForenSynths_train_val/test/progan'

# %%
#Fat blur
# !python train.py \
--name Fat-blur-4class-resnet-car-cat-chair-horse \
--dataroot /workspace/datasets/ForenSynths_train_val \
--classes car,cat,chair,horse --batch_size 32 --delr_freq 10 --lr 0.0002 --niter 50
# Out:
# ----------------- Options ---------------
#                      arch: res50
#                batch_size: 32                            	[default: 64]
#                     beta1: 0.9
#                 blur_prob: 0
#                  blur_sig: 0.5
#           checkpoints_dir: ./checkpoints
#                 class_bal: False
#                   classes: car,cat,chair,horse           	[default: ]
#            continue_train: False
#                  cropSize: 224
#                  data_aug: False
#                  dataroot: /workspace/datasets/ForenSynths_train_val	[default: ./dataset/]
#                 delr_freq: 10                            	[default: 20]
#           earlystop_epoch: 15
#                     epoch: latest
#               epoch_count: 1
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                   isTrain: True                          	[default: None]
#                jpg_method: cv2
#                  jpg_prob: 0
#                  jpg_qual: 75
#                last_epoch: -1
#                  loadSize: 256
#                 loss_freq: 400
#                        lr: 0.0002                        	[default: 0.0001]
#                      mode: binary
#                      name: Fat-blur-4class-resnet-car-cat-chair-horse2024_06_19_05_31_46	[default: experiment_name]
#                 new_optim: False
#                     niter: 50                            	[default: 1000]
#                   no_flip: False
#               num_threads: 8
#                     optim: adam
#            resize_or_crop: scale_and_crop
#                 rz_interp: bilinear
#           save_epoch_freq: 20
#          save_latest_freq: 2000
#            serial_batches: False
#                    suffix:
#               train_split: train
#                 val_split: val
# ----------------- End -------------------
# train.py  --name  Fat-blur-4class-resnet-car-cat-chair-horse  --dataroot  /workspace/datasets/ForenSynths_train_val  --classes  car,cat,chair,horse  --batch_size  32  --delr_freq  10  --lr  0.0002  --niter  50
# cwd: /workspace/NPR-DeepfakeDetection
# (Val @ epoch 0) acc: 0.5; ap: 0.5053824132850968
# acc increment 0.0 --> 0.5 - saving best model
# Saving model ./checkpoints/Fat-blur-4class-resnet-car-cat-chair-horse2024_06_19_05_31_46/model_epoch_best.pth
# (Val @ epoch 1) acc: 0.803125; ap: 0.9013773560809679
# acc increment 0.5 --> 0.803125 - saving best model
# Saving model ./checkpoints/Fat-blur-4class-resnet-car-cat-chair-horse2024_06_19_05_31_46/model_epoch_best.pth
# (Val @ epoch 2) acc: 0.651875; ap: 0.9294026762601586
# (Val @ epoch 3) acc: 0.88125; ap: 0.9599068055024124
# acc increment 0.803125 --> 0.88125 - saving best model
# Saving model ./checkpoints/Fat-blur-4class-resnet-car-cat-chair-horse2024_06_19_05_31_46/model_epoch_best.pth
# (Val @ epoch 4) acc: 0.89; ap: 0.97236610571555
# acc increment 0.88125 --> 0.89 - saving best model
# Saving model ./checkpoints/Fat-blur-4class-resnet-car-cat-chair-horse2024_06_19_05_31_46/model_epoch_best.pth
# (Val @ epoch 5) acc: 0.930625; ap: 0.9837770056419195
# acc increment 0.89 --> 0.930625 - saving best model
# Saving model ./checkpoints/Fat-blur-4class-resnet-car-cat-chair-horse2024_06_19_05_31_46/model_epoch_best.pth
# (Val @ epoch 6) acc: 0.853125; ap: 0.9805653852335522
# 2024_06_19_05_33_27 Train loss: 0.2149111032485962 at step: 400 lr 0.0002
# (Val @ epoch 7) acc: 0.924375; ap: 0.9829993693256945
# (Val @ epoch 8) acc: 0.930625; ap: 0.986967219740088
# (Val @ epoch 9) acc: 0.919375; ap: 0.9830124389823537
# 2024_06_19_05_34_07 changing lr at the end of epoch 10, iters 550
# *************************
# Changing lr from 0.0002 to 0.00018
# *************************
# (Val @ epoch 10) acc: 0.89625; ap: 0.985182611020098
# (Val @ epoch 11) acc: 0.940625; ap: 0.9903549259244978
# acc increment 0.930625 --> 0.940625 - saving best model
# Saving model ./checkpoints/Fat-blur-4class-resnet-car-cat-chair-horse2024_06_19_05_31_46/model_epoch_best.pth
# (Val @ epoch 12) acc: 0.910625; ap: 0.98209844471135
# (Val @ epoch 13) acc: 0.9325; ap: 0.9897868117066372
# (Val @ epoch 14) acc: 0.90125; ap: 0.9873610996509932
# 2024_06_19_05_35_12 Train loss: 0.06189917027950287 at step: 800 lr 0.00018
# (Val @ epoch 15) acc: 0.9225; ap: 0.9870798462509283
# (Val @ epoch 16) acc: 0.9375; ap: 0.9881323338105209
# (Val @ epoch 17) acc: 0.875; ap: 0.9850719515491697
# (Val @ epoch 18) acc: 0.9475; ap: 0.9912864017579724
# acc increment 0.940625 --> 0.9475 - saving best model
# Saving model ./checkpoints/Fat-blur-4class-resnet-car-cat-chair-horse2024_06_19_05_31_46/model_epoch_best.pth
# (Val @ epoch 19) acc: 0.8625; ap: 0.9840200037688056
# 2024_06_19_05_36_17 changing lr at the end of epoch 20, iters 1050
# *************************
# Changing lr from 0.00018 to 0.000162
# *************************
# (Val @ epoch 20) acc: 0.94125; ap: 0.9896846024984906
# (Val @ epoch 21) acc: 0.944375; ap: 0.9896850750800429
# (Val @ epoch 22) acc: 0.95375; ap: 0.9918395988061749
# acc increment 0.9475 --> 0.95375 - saving best model
# Saving model ./checkpoints/Fat-blur-4class-resnet-car-cat-chair-horse2024_06_19_05_31_46/model_epoch_best.pth
# 2024_06_19_05_36_56 Train loss: 0.008814867585897446 at step: 1200 lr 0.000162
# (Val @ epoch 23) acc: 0.95125; ap: 0.9938220093995976
# (Val @ epoch 24) acc: 0.931875; ap: 0.9857957875524856
# (Val @ epoch 25) acc: 0.8475; ap: 0.9882604829665418
# (Val @ epoch 26) acc: 0.945625; ap: 0.9917431022750159
# (Val @ epoch 27) acc: 0.925625; ap: 0.9921754700791433
# (Val @ epoch 28) acc: 0.95; ap: 0.9917656750773302
# (Val @ epoch 29) acc: 0.960625; ap: 0.9937357428160788
# acc increment 0.95375 --> 0.960625 - saving best model
# Saving model ./checkpoints/Fat-blur-4class-resnet-car-cat-chair-horse2024_06_19_05_31_46/model_epoch_best.pth
# 2024_06_19_05_38_27 changing lr at the end of epoch 30, iters 1550
# *************************
# Changing lr from 0.000162 to 0.00014580000000000002
# *************************
# (Val @ epoch 30) acc: 0.821875; ap: 0.9887537493857379
# 2024_06_19_05_38_40 Train loss: 0.0685809925198555 at step: 1600 lr 0.00014580000000000002
# (Val @ epoch 31) acc: 0.894375; ap: 0.9935554263649375
# (Val @ epoch 32) acc: 0.96875; ap: 0.9969524394630148
# acc increment 0.960625 --> 0.96875 - saving best model
# Saving model ./checkpoints/Fat-blur-4class-resnet-car-cat-chair-horse2024_06_19_05_31_46/model_epoch_best.pth
# (Val @ epoch 33) acc: 0.93375; ap: 0.9952497474010449
# (Val @ epoch 34) acc: 0.9225; ap: 0.994421851073904
# (Val @ epoch 35) acc: 0.878125; ap: 0.9902422705244547
# (Val @ epoch 36) acc: 0.95875; ap: 0.9952389173013025
# (Val @ epoch 37) acc: 0.96375; ap: 0.9930049541209889
# (Val @ epoch 38) acc: 0.93125; ap: 0.9962074804373307
# 2024_06_19_05_40_24 Train loss: 0.010287260636687279 at step: 2000 lr 0.00014580000000000002
# (Val @ epoch 39) acc: 0.92625; ap: 0.9968230499668274
# 2024_06_19_05_40_37 changing lr at the end of epoch 40, iters 2050
# *************************
# Changing lr from 0.00014580000000000005 to 0.00013122000000000003
# *************************
# (Val @ epoch 40) acc: 0.969375; ap: 0.997249822865274
# acc increment 0.96875 --> 0.969375 - saving best model
# Saving model ./checkpoints/Fat-blur-4class-resnet-car-cat-chair-horse2024_06_19_05_31_46/model_epoch_best.pth
# (Val @ epoch 41) acc: 0.956875; ap: 0.9968523278751071
# (Val @ epoch 42) acc: 0.961875; ap: 0.9955564444033879
# (Val @ epoch 43) acc: 0.97; ap: 0.9968406651267199
# acc increment 0.969375 --> 0.97 - saving best model
# Saving model ./checkpoints/Fat-blur-4class-resnet-car-cat-chair-horse2024_06_19_05_31_46/model_epoch_best.pth
# (Val @ epoch 44) acc: 0.953125; ap: 0.9958163354261357
# (Val @ epoch 45) acc: 0.96875; ap: 0.9963174909537345
# (Val @ epoch 46) acc: 0.8725; ap: 0.9913656321185901
# 2024_06_19_05_42_09 Train loss: 0.023957619443535805 at step: 2400 lr 0.00013122000000000003
# (Val @ epoch 47) acc: 0.958125; ap: 0.9957078079290198
# (Val @ epoch 48) acc: 0.913125; ap: 0.9957307780522184
# (Val @ epoch 49) acc: 0.91625; ap: 0.9970468416805899
# *************************
# 2024_06_19_05_42_39
# Traceback (most recent call last):
#   File "/workspace/NPR-DeepfakeDetection/train.py", line 114, in <module>
#     model.eval();testmodel()
#   File "/workspace/NPR-DeepfakeDetection/train.py", line 67, in testmodel
#     Testopt.classes = os.listdir(Testopt.dataroot) if multiclass[v_id] else ['']
# FileNotFoundError: [Errno 2] No such file or directory: '/workspace/datasets/ForenSynths_train_val/test/progan'

# %%
#Gradient 
# !python train.py \
--name Gradient-4class-resnet-car-cat-chair-horse \
--dataroot /workspace/datasets/ForenSynths_train_val \
--classes car,cat,chair,horse --batch_size 32 --delr_freq 10 --lr 0.0002 --niter 50
# Out:
# ----------------- Options ---------------
#                      arch: res50
#                batch_size: 32                            	[default: 64]
#                     beta1: 0.9
#                 blur_prob: 0
#                  blur_sig: 0.5
#           checkpoints_dir: ./checkpoints
#                 class_bal: False
#                   classes: car,cat,chair,horse           	[default: ]
#            continue_train: False
#                  cropSize: 224
#                  data_aug: False
#                  dataroot: /workspace/datasets/ForenSynths_train_val	[default: ./dataset/]
#                 delr_freq: 10                            	[default: 20]
#           earlystop_epoch: 15
#                     epoch: latest
#               epoch_count: 1
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                   isTrain: True                          	[default: None]
#                jpg_method: cv2
#                  jpg_prob: 0
#                  jpg_qual: 75
#                last_epoch: -1
#                  loadSize: 256
#                 loss_freq: 400
#                        lr: 0.0002                        	[default: 0.0001]
#                      mode: binary
#                      name: Gradient-4class-resnet-car-cat-chair-horse2024_06_19_09_19_47	[default: experiment_name]
#                 new_optim: False
#                     niter: 50                            	[default: 1000]
#                   no_flip: False
#               num_threads: 8
#                     optim: adam
#            resize_or_crop: scale_and_crop
#                 rz_interp: bilinear
#           save_epoch_freq: 20
#          save_latest_freq: 2000
#            serial_batches: False
#                    suffix:
#               train_split: train
#                 val_split: val
# ----------------- End -------------------
# train.py  --name  Gradient-4class-resnet-car-cat-chair-horse  --dataroot  /workspace/datasets/ForenSynths_train_val  --classes  car,cat,chair,horse  --batch_size  32  --delr_freq  10  --lr  0.0002  --niter  50
# cwd: /workspace/NPR-DeepfakeDetection
# (Val @ epoch 0) acc: 0.69; ap: 0.7610905546323836
# acc increment 0.0 --> 0.69 - saving best model
# Saving model ./checkpoints/Gradient-4class-resnet-car-cat-chair-horse2024_06_19_09_19_47/model_epoch_best.pth
# (Val @ epoch 1) acc: 0.631875; ap: 0.8449394485552838
# (Val @ epoch 2) acc: 0.790625; ap: 0.9061777000159003
# acc increment 0.69 --> 0.790625 - saving best model
# Saving model ./checkpoints/Gradient-4class-resnet-car-cat-chair-horse2024_06_19_09_19_47/model_epoch_best.pth
# (Val @ epoch 3) acc: 0.6875; ap: 0.9029387677652061
# (Val @ epoch 4) acc: 0.7275; ap: 0.9336695898030436
# (Val @ epoch 5) acc: 0.718125; ap: 0.945793168640002
# (Val @ epoch 6) acc: 0.581875; ap: 0.9196499587065439
# 2024_06_19_09_21_28 Train loss: 0.25220242142677307 at step: 400 lr 0.0002
# (Val @ epoch 7) acc: 0.70625; ap: 0.9266742683596778
# (Val @ epoch 8) acc: 0.770625; ap: 0.9646526002878902
# (Val @ epoch 9) acc: 0.87875; ap: 0.9550838566446272
# acc increment 0.790625 --> 0.87875 - saving best model
# Saving model ./checkpoints/Gradient-4class-resnet-car-cat-chair-horse2024_06_19_09_19_47/model_epoch_best.pth
# 2024_06_19_09_22_07 changing lr at the end of epoch 10, iters 550
# *************************
# Changing lr from 0.0002 to 0.00018
# *************************
# (Val @ epoch 10) acc: 0.80625; ap: 0.9706316103435164
# (Val @ epoch 11) acc: 0.918125; ap: 0.9750935466559513
# acc increment 0.87875 --> 0.918125 - saving best model
# Saving model ./checkpoints/Gradient-4class-resnet-car-cat-chair-horse2024_06_19_09_19_47/model_epoch_best.pth
# (Val @ epoch 12) acc: 0.771875; ap: 0.9707842741967491
# (Val @ epoch 13) acc: 0.9175; ap: 0.9765246172034274
# (Val @ epoch 14) acc: 0.855; ap: 0.9626421072566518
# 2024_06_19_09_23_11 Train loss: 0.11571001261472702 at step: 800 lr 0.00018
# (Val @ epoch 15) acc: 0.914375; ap: 0.9737726282900523
# (Val @ epoch 16) acc: 0.8875; ap: 0.9647638578494478
# (Val @ epoch 17) acc: 0.918125; ap: 0.9765005474201475
# (Val @ epoch 18) acc: 0.809375; ap: 0.9751039442494089
# (Val @ epoch 19) acc: 0.92375; ap: 0.9854215428943676
# acc increment 0.918125 --> 0.92375 - saving best model
# Saving model ./checkpoints/Gradient-4class-resnet-car-cat-chair-horse2024_06_19_09_19_47/model_epoch_best.pth
# 2024_06_19_09_24_17 changing lr at the end of epoch 20, iters 1050
# *************************
# Changing lr from 0.00018 to 0.000162
# *************************
# (Val @ epoch 20) acc: 0.755; ap: 0.9507318253089649
# (Val @ epoch 21) acc: 0.60625; ap: 0.9611160847761883
# (Val @ epoch 22) acc: 0.900625; ap: 0.968401652868899
# 2024_06_19_09_24_56 Train loss: 0.09716901183128357 at step: 1200 lr 0.000162
# (Val @ epoch 23) acc: 0.87; ap: 0.974557805910818
# (Val @ epoch 24) acc: 0.76; ap: 0.9814385252089548
# (Val @ epoch 25) acc: 0.935625; ap: 0.9866810226431402
# acc increment 0.92375 --> 0.935625 - saving best model
# Saving model ./checkpoints/Gradient-4class-resnet-car-cat-chair-horse2024_06_19_09_19_47/model_epoch_best.pth
# (Val @ epoch 26) acc: 0.651875; ap: 0.966775044772065
# (Val @ epoch 27) acc: 0.80625; ap: 0.9852878108757194
# (Val @ epoch 28) acc: 0.85; ap: 0.9861177219011051
# (Val @ epoch 29) acc: 0.82125; ap: 0.9774182353666938
# 2024_06_19_09_26_27 changing lr at the end of epoch 30, iters 1550
# *************************
# Changing lr from 0.000162 to 0.00014580000000000002
# *************************
# (Val @ epoch 30) acc: 0.823125; ap: 0.981292198454613
# 2024_06_19_09_26_40 Train loss: 0.030573872849345207 at step: 1600 lr 0.00014580000000000002
# (Val @ epoch 31) acc: 0.936875; ap: 0.9858990242534253
# acc increment 0.935625 --> 0.936875 - saving best model
# Saving model ./checkpoints/Gradient-4class-resnet-car-cat-chair-horse2024_06_19_09_19_47/model_epoch_best.pth
# (Val @ epoch 32) acc: 0.93; ap: 0.9880500818471021
# (Val @ epoch 33) acc: 0.77875; ap: 0.980975472182086
# (Val @ epoch 34) acc: 0.886875; ap: 0.9765341741697682
# (Val @ epoch 35) acc: 0.9325; ap: 0.9830946987710173
# (Val @ epoch 36) acc: 0.928125; ap: 0.9877390169510717
# (Val @ epoch 37) acc: 0.923125; ap: 0.9817142978367482
# (Val @ epoch 38) acc: 0.9375; ap: 0.9889625811982512
# acc increment 0.936875 --> 0.9375 - saving best model
# Saving model ./checkpoints/Gradient-4class-resnet-car-cat-chair-horse2024_06_19_09_19_47/model_epoch_best.pth
# 2024_06_19_09_28_24 Train loss: 0.23598256707191467 at step: 2000 lr 0.00014580000000000002
# (Val @ epoch 39) acc: 0.896875; ap: 0.991012545396732
# 2024_06_19_09_28_37 changing lr at the end of epoch 40, iters 2050
# *************************
# Changing lr from 0.00014580000000000005 to 0.00013122000000000003
# *************************
# (Val @ epoch 40) acc: 0.910625; ap: 0.985997558809795
# (Val @ epoch 41) acc: 0.9075; ap: 0.9902949881682507
# (Val @ epoch 42) acc: 0.92125; ap: 0.9859451916738847
# (Val @ epoch 43) acc: 0.81875; ap: 0.9841063663457442
# (Val @ epoch 44) acc: 0.928125; ap: 0.9904152481987649
# (Val @ epoch 45) acc: 0.74625; ap: 0.978452120224323
# (Val @ epoch 46) acc: 0.88375; ap: 0.9870452224847397
# 2024_06_19_09_30_08 Train loss: 0.037353042513132095 at step: 2400 lr 0.00013122000000000003
# (Val @ epoch 47) acc: 0.933125; ap: 0.9858370948243099
# (Val @ epoch 48) acc: 0.949375; ap: 0.9895810579148444
# acc increment 0.9375 --> 0.949375 - saving best model
# Saving model ./checkpoints/Gradient-4class-resnet-car-cat-chair-horse2024_06_19_09_19_47/model_epoch_best.pth
# (Val @ epoch 49) acc: 0.93625; ap: 0.98850338598
# *************************
# 2024_06_19_09_30_38
# Traceback (most recent call last):
#   File "/workspace/NPR-DeepfakeDetection/train.py", line 114, in <module>
#     model.eval();testmodel()
#   File "/workspace/NPR-DeepfakeDetection/train.py", line 67, in testmodel
#     Testopt.classes = os.listdir(Testopt.dataroot) if multiclass[v_id] else ['']
# FileNotFoundError: [Errno 2] No such file or directory: '/workspace/datasets/ForenSynths_train_val/test/progan'

# %%
#Gradient - FULL Resnet 4 layer
# !python train.py \
--name Gradient-fullresnet-4class-resnet-car-cat-chair-horse \
--dataroot /workspace/datasets/ForenSynths_train_val \
--classes car,cat,chair,horse --batch_size 32 --delr_freq 10 --lr 0.0002 --niter 50
# Out:
# ----------------- Options ---------------
#                      arch: res50
#                batch_size: 32                            	[default: 64]
#                     beta1: 0.9
#                 blur_prob: 0
#                  blur_sig: 0.5
#           checkpoints_dir: ./checkpoints
#                 class_bal: False
#                   classes: car,cat,chair,horse           	[default: ]
#            continue_train: False
#                  cropSize: 224
#                  data_aug: False
#                  dataroot: /workspace/datasets/ForenSynths_train_val	[default: ./dataset/]
#                 delr_freq: 10                            	[default: 20]
#           earlystop_epoch: 15
#                     epoch: latest
#               epoch_count: 1
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                   isTrain: True                          	[default: None]
#                jpg_method: cv2
#                  jpg_prob: 0
#                  jpg_qual: 75
#                last_epoch: -1
#                  loadSize: 256
#                 loss_freq: 400
#                        lr: 0.0002                        	[default: 0.0001]
#                      mode: binary
#                      name: Gradient-fullresnet-4class-resnet-car-cat-chair-horse2024_06_19_09_49_42	[default: experiment_name]
#                 new_optim: False
#                     niter: 50                            	[default: 1000]
#                   no_flip: False
#               num_threads: 8
#                     optim: adam
#            resize_or_crop: scale_and_crop
#                 rz_interp: bilinear
#           save_epoch_freq: 20
#          save_latest_freq: 2000
#            serial_batches: False
#                    suffix:
#               train_split: train
#                 val_split: val
# ----------------- End -------------------
# train.py  --name  Gradient-fullresnet-4class-resnet-car-cat-chair-horse  --dataroot  /workspace/datasets/ForenSynths_train_val  --classes  car,cat,chair,horse  --batch_size  32  --delr_freq  10  --lr  0.0002  --niter  50
# cwd: /workspace/NPR-DeepfakeDetection
# (Val @ epoch 0) acc: 0.565; ap: 0.532999353057954
# acc increment 0.0 --> 0.565 - saving best model
# Saving model ./checkpoints/Gradient-fullresnet-4class-resnet-car-cat-chair-horse2024_06_19_09_49_42/model_epoch_best.pth
# (Val @ epoch 1) acc: 0.5475; ap: 0.5799732880796346
# (Val @ epoch 2) acc: 0.570625; ap: 0.6091438560768795
# acc increment 0.565 --> 0.570625 - saving best model
# Saving model ./checkpoints/Gradient-fullresnet-4class-resnet-car-cat-chair-horse2024_06_19_09_49_42/model_epoch_best.pth
# (Val @ epoch 3) acc: 0.57; ap: 0.6202757208078474
# (Val @ epoch 4) acc: 0.590625; ap: 0.6220048483854222
# acc increment 0.570625 --> 0.590625 - saving best model
# Saving model ./checkpoints/Gradient-fullresnet-4class-resnet-car-cat-chair-horse2024_06_19_09_49_42/model_epoch_best.pth
# (Val @ epoch 5) acc: 0.555625; ap: 0.6409410238528376
# (Val @ epoch 6) acc: 0.53875; ap: 0.674220269300848
# 2024_06_19_09_52_31 Train loss: 0.5767780542373657 at step: 400 lr 0.0002
# (Val @ epoch 7) acc: 0.628125; ap: 0.6797695632876813
# acc increment 0.590625 --> 0.628125 - saving best model
# Saving model ./checkpoints/Gradient-fullresnet-4class-resnet-car-cat-chair-horse2024_06_19_09_49_42/model_epoch_best.pth
# (Val @ epoch 8) acc: 0.665625; ap: 0.7485332992098506
# acc increment 0.628125 --> 0.665625 - saving best model
# Saving model ./checkpoints/Gradient-fullresnet-4class-resnet-car-cat-chair-horse2024_06_19_09_49_42/model_epoch_best.pth
# (Val @ epoch 9) acc: 0.665; ap: 0.767453327867747
# 2024_06_19_09_53_36 changing lr at the end of epoch 10, iters 550
# *************************
# Changing lr from 0.0002 to 0.00018
# *************************
# (Val @ epoch 10) acc: 0.68; ap: 0.7670230283647661
# acc increment 0.665625 --> 0.68 - saving best model
# Saving model ./checkpoints/Gradient-fullresnet-4class-resnet-car-cat-chair-horse2024_06_19_09_49_42/model_epoch_best.pth
# (Val @ epoch 11) acc: 0.690625; ap: 0.7889843027233718
# acc increment 0.68 --> 0.690625 - saving best model
# Saving model ./checkpoints/Gradient-fullresnet-4class-resnet-car-cat-chair-horse2024_06_19_09_49_42/model_epoch_best.pth
# (Val @ epoch 12) acc: 0.701875; ap: 0.794694810420985
# acc increment 0.690625 --> 0.701875 - saving best model
# Saving model ./checkpoints/Gradient-fullresnet-4class-resnet-car-cat-chair-horse2024_06_19_09_49_42/model_epoch_best.pth
# (Val @ epoch 13) acc: 0.69625; ap: 0.822842395471343
# (Val @ epoch 14) acc: 0.671875; ap: 0.7848410128957563
# 2024_06_19_09_55_26 Train loss: 0.5252483487129211 at step: 800 lr 0.00018
# (Val @ epoch 15) acc: 0.625625; ap: 0.7926271561096393
# (Val @ epoch 16) acc: 0.67; ap: 0.8374051905032908
# (Val @ epoch 17) acc: 0.664375; ap: 0.791077109572205
# (Val @ epoch 18) acc: 0.75625; ap: 0.8587143780484129
# acc increment 0.701875 --> 0.75625 - saving best model
# Saving model ./checkpoints/Gradient-fullresnet-4class-resnet-car-cat-chair-horse2024_06_19_09_49_42/model_epoch_best.pth
# (Val @ epoch 19) acc: 0.773125; ap: 0.8675091915487875
# acc increment 0.75625 --> 0.773125 - saving best model
# Saving model ./checkpoints/Gradient-fullresnet-4class-resnet-car-cat-chair-horse2024_06_19_09_49_42/model_epoch_best.pth
# 2024_06_19_09_57_15 changing lr at the end of epoch 20, iters 1050
# *************************
# Changing lr from 0.00018 to 0.000162
# *************************
# (Val @ epoch 20) acc: 0.720625; ap: 0.8602434427521314
# (Val @ epoch 21) acc: 0.718125; ap: 0.8562755401602791
# (Val @ epoch 22) acc: 0.666875; ap: 0.8708931080423811
# 2024_06_19_09_58_20 Train loss: 0.40786445140838623 at step: 1200 lr 0.000162
# (Val @ epoch 23) acc: 0.69875; ap: 0.852584644652011
# (Val @ epoch 24) acc: 0.765625; ap: 0.8662883402654538
# (Val @ epoch 25) acc: 0.778125; ap: 0.8868079044747612
# acc increment 0.773125 --> 0.778125 - saving best model
# Saving model ./checkpoints/Gradient-fullresnet-4class-resnet-car-cat-chair-horse2024_06_19_09_49_42/model_epoch_best.pth
# (Val @ epoch 26) acc: 0.770625; ap: 0.898276681699415
# (Val @ epoch 27) acc: 0.711875; ap: 0.8418791498970766
# (Val @ epoch 28) acc: 0.759375; ap: 0.8809932228827878
# (Val @ epoch 29) acc: 0.57625; ap: 0.8146965999811284
# 2024_06_19_10_00_54 changing lr at the end of epoch 30, iters 1550
# *************************
# Changing lr from 0.000162 to 0.00014580000000000002
# *************************
# (Val @ epoch 30) acc: 0.779375; ap: 0.9028200800482454
# acc increment 0.778125 --> 0.779375 - saving best model
# Saving model ./checkpoints/Gradient-fullresnet-4class-resnet-car-cat-chair-horse2024_06_19_09_49_42/model_epoch_best.pth
# 2024_06_19_10_01_16 Train loss: 0.18172325193881989 at step: 1600 lr 0.00014580000000000002
# (Val @ epoch 31) acc: 0.809375; ap: 0.9264246501851466
# acc increment 0.779375 --> 0.809375 - saving best model
# Saving model ./checkpoints/Gradient-fullresnet-4class-resnet-car-cat-chair-horse2024_06_19_09_49_42/model_epoch_best.pth
# (Val @ epoch 32) acc: 0.689375; ap: 0.9028302516427933
# (Val @ epoch 33) acc: 0.775625; ap: 0.9243877891066015
# (Val @ epoch 34) acc: 0.695; ap: 0.8297579580181529
# (Val @ epoch 35) acc: 0.79375; ap: 0.9320605394278014
# (Val @ epoch 36) acc: 0.78125; ap: 0.9148690671451137
# (Val @ epoch 37) acc: 0.780625; ap: 0.9239691946807779
# (Val @ epoch 38) acc: 0.735625; ap: 0.9003579490020299
# 2024_06_19_10_04_10 Train loss: 0.16699090600013733 at step: 2000 lr 0.00014580000000000002
# (Val @ epoch 39) acc: 0.845; ap: 0.9299326050307392
# acc increment 0.809375 --> 0.845 - saving best model
# Saving model ./checkpoints/Gradient-fullresnet-4class-resnet-car-cat-chair-horse2024_06_19_09_49_42/model_epoch_best.pth
# 2024_06_19_10_04_32 changing lr at the end of epoch 40, iters 2050
# *************************
# Changing lr from 0.00014580000000000005 to 0.00013122000000000003
# *************************
# (Val @ epoch 40) acc: 0.83875; ap: 0.9359578091909015
# (Val @ epoch 41) acc: 0.785; ap: 0.9289730464384807
# (Val @ epoch 42) acc: 0.83125; ap: 0.9447813092394246
# (Val @ epoch 43) acc: 0.84125; ap: 0.9323011878039374
# (Val @ epoch 44) acc: 0.82375; ap: 0.9366066088075413
# (Val @ epoch 45) acc: 0.84125; ap: 0.9421852700437041
# (Val @ epoch 46) acc: 0.8425; ap: 0.9466100867223164
# 2024_06_19_10_07_05 Train loss: 0.2711445093154907 at step: 2400 lr 0.00013122000000000003
# (Val @ epoch 47) acc: 0.71125; ap: 0.925924791198876
# (Val @ epoch 48) acc: 0.78125; ap: 0.9444000876396874
# (Val @ epoch 49) acc: 0.836875; ap: 0.9510315071974454
# *************************
# 2024_06_19_10_07_55
# Traceback (most recent call last):
#   File "/workspace/NPR-DeepfakeDetection/train.py", line 114, in <module>
#     model.eval();testmodel()
#   File "/workspace/NPR-DeepfakeDetection/train.py", line 67, in testmodel
#     Testopt.classes = os.listdir(Testopt.dataroot) if multiclass[v_id] else ['']
# FileNotFoundError: [Errno 2] No such file or directory: '/workspace/datasets/ForenSynths_train_val/test/progan'

# %% [markdown]
# ## Test mode

# %%
# !ls checkpoints/*/*.pth
# Out:
# checkpoints/Gaussblur-4class-resnet-car-cat-chair-horse2024_06_19_02_28_49/model_epoch_best.pth
# checkpoints/NPR-highpass-4class-resnet-car-cat-chair-horse2024_06_19_03_02_23/model_epoch_best.pth
# checkpoints/NRP-4class-resnet-car-cat-chair-horse2024_06_19_01_57_03/model_epoch_last.pth
# checkpoints/NRP-4class-resnet-car-cat-chair-horse2024_06_19_02_03_47/model_epoch_best.pth

# %%
#!ls checkpoints/*/*.pth
import os
pattern = 'NRP-4class'
model_paths=[]
model_path = ''
pths = []
for a,b,c in os.walk('checkpoints'):
    if len(c)>0:
        names = [os.path.join(a,i) for i in c if 'best' in i]
        if names is not None:
            model_paths.extend(names)

model_paths = [i for i in model_paths if pattern in i]
if len(model_paths)>0:
    model_path = model_paths[-1]
print(model_path)
# Out:
# checkpoints/NRP-4class-resnet-car-cat-chair-horse2024_06_19_10_23_11/model_epoch_best.pth

# %%
# !ls checkpoints/*/*.pth

# %%
# !python test.py --model_path $model_path --batch_size 32
# Out:
# Model_path checkpoints/NRP-4class-resnet-car-cat-chair-horse2024_06_19_10_23_11/model_epoch_best.pth
# ===================================================
#                  CNN_systh_testset
# ===================================================
# 2024_06_19_10_33_35
# (0 biggan      ) acc: 64.5; ap: 79.3
# (1 crn         ) acc: 50.6; ap: 96.5
# (2 cyclegan    ) acc: 59.6; ap: 71.7
# (3 deepfake    ) acc: 71.6; ap: 68.8
# (4 gaugan      ) acc: 50.4; ap: 57.5
# (5 imle        ) acc: 50.6; ap: 96.5
# (6 progan      ) acc: 97.9; ap: 99.7
# (7 san         ) acc: 63.9; ap: 74.1
# (8 seeingdark  ) acc: 69.4; ap: 67.0
# (9 stargan     ) acc: 68.9; ap: 99.7
# (10 stylegan    ) acc: 85.2; ap: 94.0
# (11 stylegan2   ) acc: 87.1; ap: 97.1
# (12 whichfaceisreal) acc: 46.0; ap: 46.3
# (13 Mean      ) acc: 66.6; ap: 80.6
# *************************
# ======================================================
#                   DiffusionForensics
# ======================================================
# 2024_06_19_10_38_13
# (0 adm         ) acc: 72.0; ap: 92.8
# (1 dalle2      ) acc: 79.8; ap: 78.3
# (2 ddpm        ) acc: 89.2; ap: 99.2
# (3 diff-projectedgan) acc: 63.0; ap: 97.8
# (4 diff-stylegan) acc: 88.5; ap: 99.7
# (5 iddpm       ) acc: 80.5; ap: 94.4
# (6 if          ) acc: 80.9; ap: 91.9
# (7 ldm         ) acc: 98.9; ap: 100.0
# (8 midjourney  ) acc: 87.7; ap: 77.4
# (9 pndm        ) acc: 54.5; ap: 94.2
# (10 projectedgan) acc: 66.5; ap: 98.1
# (11 sdv1        ) acc: 77.2; ap: 98.9
# (12 sdv2        ) acc: 85.6; ap: 95.4
# (13 stylegan_official) acc: 70.8; ap: 96.9
# (14 vqdiffusion ) acc: 88.3; ap: 99.8
# (15 Mean      ) acc: 78.9; ap: 94.3
# *************************

# %%
# !python test.py --model_path $model_path --batch_size 32
# Out:
# Model_path checkpoints/NRP-4class-resnet-car-cat-chair-horse2024_06_19_02_03_47/model_epoch_best.pth
# ===================================================
#                  CNN_systh_testset
# ===================================================
# 2024_06_19_02_21_32
# (0 biggan      ) acc: 64.1; ap: 80.6
# (1 crn         ) acc: 50.9; ap: 88.3
# (2 cyclegan    ) acc: 56.1; ap: 65.3
# (3 deepfake    ) acc: 72.1; ap: 77.2
# (4 gaugan      ) acc: 50.2; ap: 56.5
# (5 imle        ) acc: 50.9; ap: 88.3
# (6 progan      ) acc: 98.6; ap: 99.8
# (7 san         ) acc: 63.0; ap: 74.0
# (8 seeingdark  ) acc: 68.3; ap: 70.1
# (9 stargan     ) acc: 71.7; ap: 97.9
# (10 stylegan    ) acc: 85.9; ap: 94.1
# (11 stylegan2   ) acc: 92.3; ap: 98.6
# (12 whichfaceisreal) acc: 44.1; ap: 45.1
# (13 Mean      ) acc: 66.8; ap: 79.7
# *************************

# %%
# !python test.py --model_path checkpoints/Gaussblur-4class-resnet-car-cat-chair-horse2024_06_19_02_28_49/model_epoch_best.pth --batch_size 32
# Out:
# Model_path checkpoints/Gaussblur-4class-resnet-car-cat-chair-horse2024_06_19_02_28_49/model_epoch_best.pth
# ======================================================
#                   DiffusionForensics
# ======================================================
# 2024_06_19_05_20_02
# (0 adm         ) acc: 71.5; ap: 87.6
# (1 dalle2      ) acc: 90.7; ap: 94.2
# (2 ddpm        ) acc: 90.8; ap: 99.3
# (3 diff-projectedgan) acc: 95.8; ap: 99.9
# (4 diff-stylegan) acc: 93.2; ap: 99.8
# (5 iddpm       ) acc: 62.1; ap: 97.9
# (6 if          ) acc: 87.8; ap: 95.9
# (7 ldm         ) acc: 99.7; ap: 100.0
# (8 midjourney  ) acc: 95.3; ap: 98.2
# (9 pndm        ) acc: 51.3; ap: 89.5
# (10 projectedgan) acc: 93.8; ap: 99.9
# (11 sdv1        ) acc: 70.1; ap: 95.9
# (12 sdv2        ) acc: 91.7; ap: 97.5
# (13 stylegan_official) acc: 67.6; ap: 97.9
# (14 vqdiffusion ) acc: 67.7; ap: 99.3
# (15 Mean      ) acc: 81.9; ap: 96.9
# *************************

# %%
# !python test.py --model_path $model_path --batch_size 32
# Out:
# Model_path checkpoints/Gaussblur-4class-resnet-car-cat-chair-horse2024_06_19_02_28_49/model_epoch_best.pth
# ===================================================
#                  CNN_systh_testset
# ===================================================
# 2024_06_19_02_37_31
# (0 biggan      ) acc: 67.0; ap: 78.1
# (1 crn         ) acc: 50.1; ap: 68.6
# (2 cyclegan    ) acc: 64.0; ap: 78.4
# (3 deepfake    ) acc: 65.4; ap: 52.0
# (4 gaugan      ) acc: 50.3; ap: 55.2
# (5 imle        ) acc: 50.1; ap: 86.0
# (6 progan      ) acc: 98.7; ap: 99.9
# (7 san         ) acc: 65.5; ap: 79.1
# (8 seeingdark  ) acc: 65.3; ap: 63.2
# (9 stargan     ) acc: 99.0; ap: 100.0
# (10 stylegan    ) acc: 80.9; ap: 93.3
# (11 stylegan2   ) acc: 96.6; ap: 99.6
# (12 whichfaceisreal) acc: 45.4; ap: 45.5
# (13 Mean      ) acc: 69.1; ap: 76.8
# *************************

# %%
# !python test.py --model_path $model_path --batch_size 32
# Out:
# Model_path checkpoints/NPR-highpass-4class-resnet-car-cat-chair-horse2024_06_19_03_02_23/model_epoch_best.pth
# ===================================================
#                  CNN_systh_testset
# ===================================================
# 2024_06_19_03_19_46
# (0 biggan      ) acc: 63.0; ap: 65.9
# (1 crn         ) acc: 52.7; ap: 47.2
# (2 cyclegan    ) acc: 50.5; ap: 49.1
# (3 deepfake    ) acc: 50.1; ap: 50.5
# (4 gaugan      ) acc: 34.4; ap: 36.7
# (5 imle        ) acc: 34.1; ap: 35.7
# (6 progan      ) acc: 83.3; ap: 91.9
# (7 san         ) acc: 44.5; ap: 46.5
# (8 seeingdark  ) acc: 60.0; ap: 66.4
# (9 stargan     ) acc: 50.1; ap: 58.6
# (10 stylegan    ) acc: 70.0; ap: 82.7
# (11 stylegan2   ) acc: 73.7; ap: 84.1
# (12 whichfaceisreal) acc: 47.5; ap: 46.7
# (13 Mean      ) acc: 54.9; ap: 58.6
# *************************

# %%
# !python test.py --model_path $model_path --batch_size 32
# Out:
# Model_path checkpoints/NPR-lowpass-4class-resnet-car-cat-chair-horse2024_06_19_03_28_12/model_epoch_best.pth
# ===================================================
#                  CNN_systh_testset
# ===================================================
# 2024_06_19_03_38_54
# (0 biggan      ) acc: 62.3; ap: 82.0
# (1 crn         ) acc: 50.2; ap: 82.6
# (2 cyclegan    ) acc: 48.4; ap: 51.7
# (3 deepfake    ) acc: 52.4; ap: 69.0
# (4 gaugan      ) acc: 50.9; ap: 61.8
# (5 imle        ) acc: 50.2; ap: 83.8
# (6 progan      ) acc: 95.0; ap: 98.7
# (7 san         ) acc: 69.9; ap: 79.2
# (8 seeingdark  ) acc: 59.2; ap: 61.5
# (9 stargan     ) acc: 58.8; ap: 87.3
# (10 stylegan    ) acc: 85.1; ap: 97.1
# (11 stylegan2   ) acc: 89.4; ap: 98.4
# (12 whichfaceisreal) acc: 45.8; ap: 47.2
# (13 Mean      ) acc: 62.9; ap: 77.0
# *************************

# %%
# !python test.py --model_path $model_path --batch_size 32
# Out:
# Model_path checkpoints/NPR-2branch-4class-resnet-car-cat-chair-horse2024_06_19_04_32_24/model_epoch_best.pth
# ===================================================
#                  CNN_systh_testset
# ===================================================
# 2024_06_19_04_51_55
# (0 biggan      ) acc: 54.5; ap: 57.7
# (1 crn         ) acc: 50.4; ap: 87.1
# (2 cyclegan    ) acc: 38.3; ap: 33.5
# (3 deepfake    ) acc: 49.9; ap: 65.7
# (4 gaugan      ) acc: 45.3; ap: 42.5
# (5 imle        ) acc: 50.4; ap: 87.1
# (6 progan      ) acc: 81.3; ap: 94.3
# (7 san         ) acc: 65.8; ap: 69.4
# (8 seeingdark  ) acc: 64.4; ap: 62.2
# (9 stargan     ) acc: 45.6; ap: 68.8
# (10 stylegan    ) acc: 64.6; ap: 84.1
# (11 stylegan2   ) acc: 70.3; ap: 84.7
# (12 whichfaceisreal) acc: 35.4; ap: 38.6
# (13 Mean      ) acc: 55.1; ap: 67.4
# *************************

# %%
#Fatblur test
# !python test.py --model_path $model_path --batch_size 32
# Out:
# Model_path checkpoints/Fat-blur-4class-resnet-car-cat-chair-horse2024_06_19_05_31_46/model_epoch_best.pth
# ======================================================
#                   DiffusionForensics
# ======================================================
# 2024_06_19_05_42_44
# (0 adm         ) acc: 65.2; ap: 78.0
# (1 dalle2      ) acc: 91.3; ap: 92.8
# (2 ddpm        ) acc: 79.0; ap: 98.7
# (3 diff-projectedgan) acc: 90.8; ap: 99.8
# (4 diff-stylegan) acc: 92.0; ap: 98.5
# (5 iddpm       ) acc: 55.8; ap: 91.2
# (6 if          ) acc: 94.6; ap: 98.3
# (7 ldm         ) acc: 100.0; ap: 100.0
# (8 midjourney  ) acc: 97.9; ap: 95.8
# (9 pndm        ) acc: 50.0; ap: 49.4
# (10 projectedgan) acc: 94.8; ap: 99.8
# (11 sdv1        ) acc: 58.7; ap: 90.5
# (12 sdv2        ) acc: 93.2; ap: 97.0
# (13 stylegan_official) acc: 79.8; ap: 95.9
# (14 vqdiffusion ) acc: 63.7; ap: 97.1
# (15 Mean      ) acc: 80.4; ap: 92.2
# *************************

# %%
#Gradient test
# !python test.py --model_path $model_path --batch_size 32
# Out:
# Model_path checkpoints/Gradient-4class-resnet-car-cat-chair-horse2024_06_19_09_19_47/model_epoch_best.pth
# ======================================================
#                   DiffusionForensics
# ======================================================
# 2024_06_19_09_30_43
# (0 adm         ) acc: 88.2; ap: 96.4
# (1 dalle2      ) acc: 88.7; ap: 99.5
# (2 ddpm        ) acc: 97.7; ap: 99.5
# (3 diff-projectedgan) acc: 97.8; ap: 99.7
# (4 diff-stylegan) acc: 97.6; ap: 99.7
# (5 iddpm       ) acc: 96.1; ap: 99.4
# (6 if          ) acc: 91.4; ap: 99.8
# (7 ldm         ) acc: 99.4; ap: 100.0
# (8 midjourney  ) acc: 84.6; ap: 99.7
# (9 pndm        ) acc: 85.4; ap: 98.3
# (10 projectedgan) acc: 96.7; ap: 99.5
# (11 sdv1        ) acc: 88.4; ap: 98.1
# (12 sdv2        ) acc: 91.0; ap: 99.2
# (13 stylegan_official) acc: 94.8; ap: 99.3
# (14 vqdiffusion ) acc: 99.4; ap: 99.8
# (15 Mean      ) acc: 93.1; ap: 99.2
# *************************

# %%
#Gradient test
# !python test.py --model_path $model_path --batch_size 32
# Out:
# Model_path checkpoints/Gradient-4class-resnet-car-cat-chair-horse2024_06_19_09_19_47/model_epoch_best.pth
# ===================================================
#                  CNN_systh_testset
# ===================================================
# 2024_06_19_09_36_09
# (0 biggan      ) acc: 72.1; ap: 80.1
# (1 crn         ) acc: 50.0; ap: 67.6
# (2 cyclegan    ) acc: 72.1; ap: 74.0
# (3 deepfake    ) acc: 81.6; ap: 91.9
# (4 gaugan      ) acc: 54.3; ap: 54.1
# (5 imle        ) acc: 50.0; ap: 69.7
# (6 progan      ) acc: 97.0; ap: 99.6
# (7 san         ) acc: 52.3; ap: 54.0
# (8 seeingdark  ) acc: 55.6; ap: 47.9
# (9 stargan     ) acc: 98.0; ap: 100.0
# (10 stylegan    ) acc: 93.8; ap: 98.6
# (11 stylegan2   ) acc: 93.1; ap: 98.5
# (12 whichfaceisreal) acc: 55.0; ap: 58.8
# (13 Mean      ) acc: 71.1; ap: 76.5
# *************************

# %%
#Gradient full resnet test
# !python test.py --model_path $model_path --batch_size 32
# Out:
# Model_path checkpoints/Gradient-fullresnet-4class-resnet-car-cat-chair-horse2024_06_19_09_49_42/model_epoch_best.pth
# ===================================================
#                  CNN_systh_testset
# ===================================================
# 2024_06_19_10_08_01
# (0 biggan      ) acc: 62.1; ap: 67.1
# (1 crn         ) acc: 50.3; ap: 64.3
# (2 cyclegan    ) acc: 57.9; ap: 67.1
# (3 deepfake    ) acc: 69.3; ap: 79.5
# (4 gaugan      ) acc: 55.4; ap: 55.5
# (5 imle        ) acc: 50.5; ap: 66.4
# (6 progan      ) acc: 90.0; ap: 97.2
# (7 san         ) acc: 45.2; ap: 50.6
# (8 seeingdark  ) acc: 45.0; ap: 37.5
# (9 stargan     ) acc: 97.4; ap: 99.9
# (10 stylegan    ) acc: 89.3; ap: 96.2
# (11 stylegan2   ) acc: 88.0; ap: 95.2
# (12 whichfaceisreal) acc: 51.9; ap: 56.8
# (13 Mean      ) acc: 65.5; ap: 71.8
# *************************

# %%
#Gradient full resnet test
# !python test.py --model_path $model_path --batch_size 32
# Out:
# Model_path checkpoints/Gradient-fullresnet-4class-resnet-car-cat-chair-horse2024_06_19_09_49_42/model_epoch_best.pth
# ======================================================
#                   DiffusionForensics
# ======================================================
# 2024_06_19_10_15_16
# (0 adm         ) acc: 80.7; ap: 92.1
# (1 dalle2      ) acc: 70.1; ap: 98.7
# (2 ddpm        ) acc: 90.3; ap: 98.0
# (3 diff-projectedgan) acc: 89.8; ap: 96.8
# (4 diff-stylegan) acc: 92.0; ap: 98.6
# (5 iddpm       ) acc: 90.3; ap: 97.5
# (6 if          ) acc: 77.3; ap: 98.9
# (7 ldm         ) acc: 92.9; ap: 100.0
# (8 midjourney  ) acc: 59.3; ap: 87.2
# (9 pndm        ) acc: 91.7; ap: 95.6
# (10 projectedgan) acc: 89.0; ap: 96.1
# (11 sdv1        ) acc: 77.9; ap: 93.2
# (12 sdv2        ) acc: 77.4; ap: 98.0
# (13 stylegan_official) acc: 91.2; ap: 98.0
# (14 vqdiffusion ) acc: 92.8; ap: 99.8
# (15 Mean      ) acc: 84.2; ap: 96.6
# *************************

# %%
# !du -h /workspace/dataset/DiffusionForensics
# Out:
# du: cannot access '/workspace/dataset1/DiffusionForensics': No such file or directory

# %% [markdown]
# ## Download data

# %%
import gdown
#https://drive.google.com/file/d/1ytZBMhTWZ6pGrrzID2a7mPASLKOWGhri/view?usp=drive_link
# Google Drive file ID
#https://drive.google.com/file/d/1bRoQiBDlBo1tkpmYJNzxuwwFgxVkGAUj/view?usp=drive_link
#https://drive.usercontent.google.com/download?id=1z_fD3UKgWQyOTZIBbYSaQ-hz4AzUrLC1&export=download&authuser=0&confirm=t&uuid=b677c64e-ce8e-4d72-972b-a4f1d196ef06&at=APZUnTUYvxkFoYuIo9cHucqktxuE:1718759575294
file_id = '1ytZBMhTWZ6pGrrzID2a7mPASLKOWGhri'
destination = '/workspace/Progan_val.zip'  # Desired file name and extension

# Construct the download URL
url = f'https://drive.google.com/uc?id={file_id}'

# Download the file
gdown.download(url, destination, quiet=False)
